# %% [markdown]
# # DEMO: OSS-Fuzz Research Module Prototype

# %% [markdown]
# ## In Brief

# %% [markdown]
# This notebook showcases prototype for an **OSS-Fuzz module for researchers** and explains some of the design decision behind it.
#
# In its current state, it addresses the following requirements:
#
# > - Project Information Retrieval ℹ️:
# >   1. API to list all projects currently fuzzed by OSS-Fuzz.
# >   2. API to retrieve details for a specific project (e.g., language, build system, fuzzer engines used).
# >   3. Ability to filter projects based on criteria (e.g., language, library).
#
# More than to demonstrate know-how, my primary goal developing this prototype was to explore the problem domain: understand how the OSS-Fuzz project works and, thereby, how we could make it more readily accessible through a usable, intuitive Python package.
#
# ⚠️ **A word of caution**: This is very much a prototype. It assumes the easy path, responsive APIs, and a cooperative user. It makes design choices that would need discussion. It barely does error-checking and wouldn't stand a chance against a fuzzer. It simply aims to expose basic functionality with minimal, clean code.
#
# If selected, the prototype could be used as a starting point, be partially refactored to correct course, or be entirely discarded to start fresh — I'm not married to it. Whether I'm selected or not, if any of its code could be useful to boostrap the project, feel free to use it.

# %% [markdown]
# ## Demo

# %%
import api as ossfuzz

from pprint import pprint as pp

# %% [markdown]
# ### Requirement 1:
#
# > API to list all projects currently fuzzed by OSS-Fuzz.
#
# This requirement implied an important design decision: **What to use as data source?** Should we clone `oss-fuzz` locally and keep it synced? Should we access the project via GitHub's API to always get fresh data? Are appropriate APIs even available?
#
# To answer these question, I gauged the amount of data we'd need to retrieve, looked for inspiration in projects that integrate with `oss-fuzz`, such as `fuzz-introspector`, and explored GitHub's [REST](https://docs.github.com/en/rest?apiVersion=2022-11-28) and [GraphQL](https://docs.github.com/en/graphql) APIs and put them to the test.
#
# **Design Decision: Small Data Source**
#
# For this functionality, I decided to use GitHub's REST API because it's simple, quick, always gets fresh data, and doesn't require authentication for our demo use. However, by then, I also knew the REST API wouldn't be sufficent for more advanced functionality. Nonetheless, since this is a prototype and exploratory by nature, it thought it interesting to use multiple data sources.
#
# Knowing this was a subjective design decision, and for the sake of separation of concerns, I deferred data fetching to a dedicated module (`fetcher.py`), to make it easy to swap data sources.

# %%
# List 5 projects
ossfuzz.list_projects(limit=5)  # The limit param is mainly for debugging
# Out:
# ['abseil-cpp', 'abseil-py', 'ada-url', 'adal', 'aiohttp']

# %%
# List all projects
ossfuzz.list_projects()
# Out:
# ['abseil-cpp',
#  'abseil-py',
#  'ada-url',
#  'adal',
#  'aiohttp',
#  'airflow',
#  'alembic',
#  'ampproject',
#  'angular',
#  'angus-mail',
#  'aniso8601',
#  'ansible',
#  'antlr3-java',
#  'antlr4-java',
#  'apache-axis2',
#  'apache-commons-bcel',
#  'apache-commons-beanutils',
#  'apache-commons-cli',
#  'apache-commons-codec',
#  'apache-commons-collections',
#  'apache-commons-compress',
#  'apache-commons-configuration',
#  'apache-commons-csv',
#  'apache-commons-fileupload',
#  'apache-commons-geometry',
#  'apache-commons-imaging',
#  'apache-commons-io',
#  'apache-commons-jxpath',
#  'apache-commons-lang',
#  'apache-commons-logging',
#  'apache-commons-math',
#  'apache-commons-net',
#  'apache-commons-text',
#  'apache-commons-validator',
#  'apache-cxf',
#  'apache-doris',
#  'apache-felix-dev',
#  'apache-httpd',
#  'apache-logging-log4cxx',
#  'apache-poi',
#  'aptos-core',
#  'archaius-core',
#  'arduinojson',
#  'argcomplete',
#  'argo',
#  'args',
#  'args4j',
#  'arrow-java',
#  'arrow-py',
#  'arrow',
#  'askama',
#  'asn1crypto',
#  'aspectj',
#  'aspell',
#  'assimp',
#  'astc-encoder',
#  'asteval',
#  'astro-compiler',
#  'astroid',
#  'asttokens',
#  'async-http-client',
#  'atomic',
#  'attrs',
#  'augeas',
#  'autoflake',
#  'autopep8',
#  'avahi',
#  'avro',
#  'azure-sdk-for-python',
#  'babel',
#  'bad_example',
#  'bazel-rules-fuzzing-test-java',
#  'bazel-rules-fuzzing-test',
#  'bc-gh',
#  'bc-java-wycheproof',
#  'bc-java',
#  'bearssl',
#  'behaviortreecpp',
#  'bignum-fuzzer',
#  'bincode',
#  'bind9',
#  'binutils',
#  'bitcoin-core',
#  'black',
#  'blackfriday',
#  'bleach',
#  'bloaty',
#  'bls-signatures',
#  'bluez',
#  'boost-beast',
#  'boost-json',
#  'boost',
#  'boringssl',
#  'botan',
#  'botocore',
#  'bottleneck',
#  'brotli-java',
#  'brotli',
#  'brpc',
#  'brunsli',
#  'bs4',
#  'bson-rust',
#  'burntsushi-toml',
#  'bz2file',
#  'bzip2',
#  'c-ares',
#  'c-blosc',
#  'c-blosc2',
#  'cachetools',
#  'caddy',
#  'caffeine',
#  'cairo',
#  'calcite-avatica',
#  'calcite',
#  'canvg',
#  'capnproto',
#  'capstone',
#  'cascadia',
#  'casync',
#  'catapult',
#  'cbor-java',
#  'cbor2',
#  'cctz',
#  'cel-cpp',
#  'cel-go',
#  'cert-manager',
#  'cfengine',
#  'cffi',
#  'cgif',
#  'cglib',
#  'chardet',
#  'charset_normalizer',
#  'checker-framework',
#  'checkstyle',
#  'chrono',
#  'cifuzz-example',
#  'cilium',
#  'circl',
#  'civetweb',
#  'cjson',
#  'clamav',
#  'clib',
#  'click',
#  'clickhouse',
#  'clock',
#  'closure-compiler',
#  'closure-library',
#  'cloud-custodian',
#  'cloud-hypervisor',
#  'cmake',
#  'cmark',
#  'cockroachdb',
#  'compress',
#  'config-validator',
#  'configparser',
#  'connectedhomeip',
#  'connexion',
#  'containerd',
#  'coreutils',
#  'cosign',
#  'cosmos-sdk',
#  'coturn',
#  'coveragepy',
#  'cpp-httplib',
#  'cppcheck',
#  'cppitertools',
#  'cpuinfo',
#  'cpython3',
#  'cras',
#  'cri-o',
#  'croaring',
#  'cron-utils',
#  'croniter',
#  'crossplane',
#  'crosvm',
#  'crow',
#  'cryptofuzz',
#  'cryptography',
#  'cryptsetup',
#  'cssselect',
#  'cubefs',
#  'cups-filters',
#  'cups',
#  'cura-engine',
#  'curl',
#  'curvesapi',
#  'cxxopts',
#  'cyclonedds',
#  'd3',
#  'dapr',
#  'dart',
#  'dask',
#  'data-encoding',
#  'date',
#  'dateparser',
#  'dav1d',
#  'dbus-broker',
#  'decorator',
#  'defusedxml',
#  'demangle',
#  'dgraph',
#  'digest',
#  'dill',
#  'distlib',
#  'distribution',
#  'django',
#  'dlplibs',
#  'dng_sdk',
#  'dnsmasq',
#  'dnspython',
#  'docker-client',
#  'docutils',
#  'dom4j',
#  'double-conversion',
#  'dovecot',
#  'dpp',
#  'draco',
#  'dragonfly',
#  'dropbear',
#  'dropwizard',
#  'duckdb',
#  'dulwich',
#  'e2fsprogs',
#  'easywsclient',
#  'ecc-diff-fuzzer',
#  'ecdsa-python',
#  'eclipse-equinox',
#  'edk2',
#  'eigen',
#  'elfutils',
#  'envoy',
#  'esp-v2',
#  'espeak-ng',
#  'et-xmlfile',
#  'etcd',
#  'evo-inflector',
#  'example',
#  'exiv2',
#  'exp4j',
#  'expat',
#  'expr',
#  'exprtk',
#  'faad2',
#  'fabric',
#  'face',
#  'fast-dds',
#  'fast-xml-parser',
#  'fast_float',
#  'fastcsv',
#  'fasthttp',
#  'fastify',
#  'fastjson',
#  'fastjson2',
#  'feign',
#  'ffmpeg',
#  'ffms2',
#  'fftw3',
#  'file',
#  'filelock',
#  'filesystem_spec',
#  'fio',
#  'fips203',
#  'firefox',
#  'firestore',
#  'flac',
#  'flask-jwt-extended',
#  'flask-restx',
#  'flask-wtf',
#  'flask',
#  'flatbuffers',
#  'flate2-rs',
#  'flex',
#  'fluent-bit',
#  'fluxcd',
#  'flyway',
#  'fmt',
#  'fontations',
#  'fonttools',
#  'freeimage',
#  'freeradius',
#  'freerdp',
#  'freetype2',
#  'fribidi',
#  'frr',
#  'fsnotify',
#  'ftfy',
#  'fuzzing-puzzles',
#  'fuzztest-example',
#  'fuzztest-raksha',
#  'fuzzywuzzy',
#  'fwupd',
#  'g-api-auth-httplib2',
#  'g-api-auth-library-python',
#  'g-api-pubsub',
#  'g-api-py-api-common-protos',
#  'g-api-py-oauthlib',
#  'g-api-python-bigquery-storage',
#  'g-api-python-client',
#  'g-api-python-cloud-core',
#  'g-api-python-firestore',
#  'g-api-python-tasks',
#  'g-api-resource-manager',
#  'g-api-resumable-media-python',
#  'g-api-secret-manager',
#  'g-apis-py-api-core',
#  'g-auth-library-java',
#  'g-cloud-logging-py',
#  'g-http-java-client',
#  'g-oauth-java-client',
#  'g-py-bigquery',
#  'g-py-crc32c',
#  'gast',
#  'gc-iam',
#  'gcloud-error-py',
#  'gcloud-go',
#  'gcp-python-cloud-storage',
#  'gdal',
#  'gdbm',
#  'gdk-pixbuf',
#  'genshi',
#  'geos',
#  'gfwx',
#  'ghostscript',
#  'giflib',
#  'gimli',
#  'git',
#  'gitdb',
#  'gitea',
#  'github_scarecrow',
#  'gitoxide',
#  'gitpython',
#  'glaze',
#  'glib',
#  'glog',
#  'glom',
#  'glslang',
#  'gluon',
#  'gnucobol',
#  'gnupg',
#  'gnutls',
#  'go-attestation',
#  'go-cmp',
#  'go-coap',
#  'go-containerregistry',
#  'go-coredns',
#  'go-dhcp',
#  'go-dns',
#  'go-ethereum',
#  'go-git',
#  'go-humanize',
#  'go-json-iterator',
#  'go-ldap',
#  'go-ole',
#  'go-pprof',
#  'go-readline',
#  'go-redis',
#  'go-sftp',
#  'go-shlex',
#  'go-snappy',
#  'go-sqlite3',
#  'go-toml',
#  'go-yaml',
#  'gobgp',
#  'gogo-protobuf',
#  'golang-appengine',
#  'golang-protobuf',
#  'golang',
#  'gonids',
#  'gopacket',
#  'gopsutil',
#  'gosnmp',
#  'gpac',
#  'gprof2dot',
#  'gpsd',
#  'graphicsfuzz-spirv',
#  'graphicsmagick',
#  'graphql-java',
#  'greenmail',
#  'grok',
#  'groovy',
#  'grpc-gateway',
#  'grpc-go',
#  'grpc-httpjson-transcoding',
#  'grpc-py',
#  'grpc-swift',
#  'gson',
#  'gss-ntlmssp',
#  'gstreamer',
#  'guava',
#  'guetzli',
#  'guice',
#  'gunicorn',
#  'gwt',
#  'h11',
#  'h2database',
#  'h2o',
#  'h3',
#  'h5py',
#  'hadoop',
#  'halide',
#  'hamcrest',
#  'haproxy',
#  'harfbuzz',
#  'hcl',
#  'hdf5',
#  'hdrhistogram',
#  'helm',
#  'hermes',
#  'hibernate-orm',
#  'hibernate-validator',
#  'highwayhash',
#  'hikaricp',
#  'hiredis-py',
#  'hiredis',
#  'hive',
#  'hoextdown',
#  'hostap',
#  'hpn-ssh',
#  'hsqldb',
#  'html2text',
#  'html5lib-python',
#  'htmlunit',
#  'htslib',
#  'http-parser',
#  'http-pattern-matcher',
#  'httparse',
#  'httpcomponents-client',
#  'httpcomponents-core',
#  'httpcore',
#  'httplib2',
#  'httpretty',
#  'httpx',
#  'hugo',
#  'hunspell',
#  'hwloc',
#  'hyperium',
#  'ibmswtpm2',
#  'ical4j',
#  'icalendar',
#  'icu',
#  'idna',
#  'igraph',
#  'ijson',
#  'image-png',
#  'image-rs',
#  'imageio',
#  'imagemagick',
#  'immer',
#  'importlib_metadata',
#  'inchi',
#  'influxdb',
#  'iniconfig',
#  'inih',
#  'ion-java',
#  'ipaddress',
#  'ipfs',
#  'ipykernel',
#  'ipython',
#  'iroha',
#  'irssi',
#  'isodate',
#  'istio-ztunnel',
#  'istio',
#  'itext7',
#  'itoa',
#  'itsdangerous',
#  'iverilog',
#  'ja3',
#  'jackson-core',
#  'jackson-databind',
#  'jackson-dataformat-xml',
#  'jackson-dataformats-binary',
#  'jackson-dataformats-text',
#  'jackson-datatype-joda',
#  'jackson-datatypes-collections',
#  'jackson-modules-java8',
#  'jakarta-mail-api',
#  'janet',
#  'janino',
#  'jansi',
#  'jansson',
#  'janus-gateway',
#  'java-diff-utils',
#  'java-example',
#  'java-jwt',
#  'java-uuid-generator',
#  'java-xmlbuilder',
#  'javacpp',
#  'javaparser',
#  'javapoet',
#  'javascript-example',
#  'javassist',
#  'javy',
#  'jaxb',
#  'jbig2dec',
#  'jboss-logging',
#  'jc',
#  'jdom',
#  'jedi',
#  'jedis',
#  'jersey',
#  'jettison',
#  'jetty',
#  'jflex',
#  'jfreechart',
#  'jimfs',
#  'jimp',
#  'jinja2',
#  'jline3',
#  'jmespathpy',
#  'jmh',
#  'joblib',
#  'joda-convert',
#  'joda-time',
#  'jolt',
#  'joni',
#  'jooq',
#  'jopt-simple',
#  'jose4j',
#  'jpeg-js',
#  'jpegoptim',
#  'jq',
#  'js-yaml',
#  'jsc',
#  'jsch',
#  'jsemver',
#  'jsign',
#  'jsmin',
#  'json-c',
#  'json-flattener',
#  'json-java',
#  'json-patch',
#  'json-sanitizer',
#  'json-simple',
#  'json-smart-v2',
#  'json',
#  'json2avro',
#  'json5format',
#  'jsoncons',
#  'jsoncpp',
#  'jsonnet',
#  'jsonp-api',
#  'jsonparser',
#  'jsonpath',
#  'jsonpickle',
#  'jsonschema',
#  'jsoup',
#  'jsqlparser',
#  'jstl-api',
#  'jts',
#  'juju',
#  'jul-to-slf4j',
#  'junrar',
#  'jupyter-nbconvert',
#  'jupyter_server',
#  'jupytext',
#  'jwt-verify-lib',
#  'jxls',
#  'kafka',
#  'kamailio',
#  'karchive',
#  'kcodecs',
#  'keras',
#  'keycloak',
#  'keystone',
#  'kie-soup',
#  'kimageformats',
#  'kiwisolver',
#  'knative',
#  'knot-dns',
#  'krb5',
#  'kryo',
#  'kubearmor',
#  'kubeedge',
#  'kubernetes-cluster-api',
#  'kubernetes',
#  'kubevirt',
#  'kyverno',
#  'lame',
#  'lark-parser',
#  'lcms',
#  'leptonica',
#  'leveldb',
#  'libaom',
#  'libarchive',
#  'libass',
#  'libavc',
#  'libavif',
#  'libbpf',
#  'libcacard',
#  'libcbor',
#  'libcoap',
#  'libconfig',
#  'libcst',
#  'libcue',
#  'libcups',
#  'libdwarf',
#  'libecc',
#  'libevent',
#  'libexif',
#  'libfdk-aac',
#  'libfido2',
#  'libfuse',
#  'libgd',
#  'libgit2',
#  'libheif',
#  'libhevc',
#  'libhtp',
#  'libical',
#  'libidn',
#  'libidn2',
#  'libiec61850',
#  'libigl',
#  'libjpeg-turbo',
#  'libjxl',
#  'libldac',
#  'liblouis',
#  'libmicrohttpd',
#  'libmodbus',
#  'libmpeg2',
#  'liboqs',
#  'libpcap',
#  'libpg_query',
#  'libphonenumber',
#  'libplist',
#  'libpng-proto',
#  'libpng',
#  'libprotobuf-mutator',
#  'libproxy',
#  'libpsl',
#  'libra',
#  'libraw',
#  'librawspeed',
#  'librdkafka',
#  'libredwg',
#  'libreoffice',
#  'libressl',
#  'librosa',
#  'librsvg',
#  'libsass',
#  'libsndfile',
#  'libsodium',
#  'libsoup',
#  'libspdm',
#  'libspectre',
#  'libspng',
#  'libsrtp',
#  'libssh',
#  'libssh2',
#  'libstdcpp',
#  'libtasn1',
#  'libteken',
#  'libtheora',
#  'libtiff',
#  'libtorrent',
#  'libtpms',
#  'libtsm',
#  'libucl',
#  'libultrahdr',
#  'libunwind',
#  'libusb',
#  'libvips',
#  'libvnc',
#  'libvpx',
#  'libwebp',
#  'libwebsockets',
#  'libxaac',
#  'libxls',
#  'libxlsxwriter',
#  'libxml2',
#  'libxslt',
#  'libyal',
#  'libyaml',
#  'libyang',
#  'libyuv',
#  'libzip',
#  'libzmq',
#  'lighttpd',
#  'lima',
#  'linkerd2-proxy',
#  'linkerd2',
#  'lit',
#  'litmuschaos',
#  'llamacpp',
#  'lldb-eval',
#  'lldpd',
#  'llhttp',
#  'llvm',
#  'llvm_libcxx',
#  'llvm_libcxxabi',
#  'lodash',
#  'lodepng',
#  'log4j2',
#  'logback',
#  'loki',
#  'looker-sdk',
#  'lotus',
#  'lua',
#  'lucene',
#  'lwan',
#  'lxc',
#  'lxml',
#  'lz4',
#  'lz4_flex',
#  'lzma',
#  'lzo',
#  'magic-enum',
#  'magic-modules',
#  'mako',
#  'mandelbulber',
#  'mapserver',
#  'mariadb-connector-j',
#  'mariadb',
#  'markdown-it-py',
#  'markupsafe',
#  'matio',
#  'matplotlib',
#  'maven-model',
#  'maven',
#  'mbedtls',
#  'mccabe',
#  'md4c',
#  'mdbook-i18n-helpers',
#  'mdbtools',
#  'mdit-py-plugins',
#  'mdurl',
#  'memcached',
#  'mercurial',
#  'meshoptimizer',
#  'metadata-extractor',
#  'metallb',
#  'mfcmapi',
#  'micronaut',
#  'migtd',
#  'minify',
#  'miniz',
#  'miniz_oxide',
#  'minizip',
#  'moby',
#  'monero',
#  'mongo-go-driver',
#  'mongoose',
#  'more-itertools',
#  'mosh',
#  'mosquitto',
#  'mp4parse-rust',
#  'mp4san',
#  'mpg123',
#  'mpv',
#  'mrab-regex',
#  'mruby',
#  'ms-tpm-20-ref',
#  'msal',
#  'msgpack-c',
#  'msgpack-python',
#  'msquic',
#  'mtail',
#  'muduo',
#  'multidict',
#  'multierr',
#  'muparser',
#  'mupdf',
#  'mutagen',
#  'mvel',
#  'mxj',
#  'myanmar-tools',
#  'mybatis-3',
#  'mysql-connector-j',
#  'mysql-server',
#  'naga',
#  'nanopb',
#  'nats',
#  'nbclassic',
#  'nbformat',
#  'nccl',
#  'ndpi',
#  'neomutt',
#  'neqo',
#  'nestegg',
#  'net-snmp',
#  'netaddr-py',
#  'netcdf',
#  'netdata',
#  'nettle',
#  'netty-tcnative',
#  'netty',
#  'networkmanager',
#  'networkx',
#  'nfstream',
#  'nghttp2',
#  'nginx',
#  'ngolo-fuzzing-x',
#  'ngolo-fuzzing',
#  'nimbus-jwt',
#  'ninja',
#  'njs',
#  'node-xml2js',
#  'nodejs',
#  'nokogiri',
#  'nom',
#  'notary',
#  'nss',
#  'ntlm-auth',
#  'ntlm2',
#  'ntopng',
#  'ntp',
#  'ntpsec',
#  'num-bigint',
#  'numactl',
#  'numexpr',
#  'numpy',
#  'oak',
#  'oatpp',
#  'oauth2',
#  'oauthlib',
#  'ogre',
#  'ohc',
#  'okhttp',
#  'olefile',
#  'onednn',
#  'oniguruma',
#  'open-json',
#  'open5gs',
#  'open62541',
#  'openapi-schema-validator',
#  'openbabel',
#  'opencensus-cpp',
#  'opencensus-go',
#  'opencensus-java',
#  'opencensus-python',
#  'opencsv',
#  'opencv',
#  'opendal',
#  'opendds',
#  'opendnp3',
#  'openexr',
#  'openh264',
#  'openjpeg',
#  'opennavsurf-bag',
#  'openpyxl',
#  'opensc',
#  'opensips',
#  'opensk',
#  'openslide',
#  'openssh',
#  'openssl',
#  'opentelemetry-go-contrib',
#  'opentelemetry',
#  'openthread',
#  'openvpn',
#  'openvswitch',
#  'openweave',
#  'openyurt',
#  'opt_einsum',
#  'opus',
#  'opusfile',
#  'oracle-py-cx',
#  'orjson',
#  'oscrypto',
#  'osgi',
#  'osquery',
#  'oss-fuzz-example',
#  'ossf-scorecard',
#  'ostree',
#  'ots',
#  'ox-ruby',
#  'p11-kit',
#  'p9',
#  'pacemaker',
#  'packaging',
#  'pako',
#  'pandas',
#  'paramiko',
#  'parse',
#  'parsimonious',
#  'parso',
#  'pasta',
#  'pathlib2',
#  'pborman-uuid',
#  'pcapplusplus',
#  'pcl',
#  'pcre2',
#  'pdf-js',
#  'pdfbox',
#  'pdfminersix',
#  'pdfplumber',
#  'pdoc',
#  'pem',
#  'pendulum',
#  'perfetto',
#  'pest',
#  'pffft',
#  'phmap',
#  'php',
#  'picotls',
#  'pidgin',
#  'piex',
#  'pigweed',
#  'pikepdf',
#  'pillow',
#  'pip',
#  'pistache',
#  'pjsip',
#  'plan9port',
#  'plexus-utils',
#  'ply',
#  'pngquant',
#  'poco',
#  'poppler',
#  'postfix',
#  'postgis',
#  'postgresql',
#  'powerdns',
#  'powsybl-java',
#  'presidio',
#  'presto',
#  'proftpd',
#  'proj4',
#  'prometheus',
#  'promise-polyfill',
#  'prost',
#  'proto-plus-python',
#  'protobuf-c',
#  'protobuf-java',
#  'protobuf-js',
#  'protobuf-python',
#  'protoc-gen-validate',
#  'protocompile',
#  'proton-bridge',
#  'proxygen',
#  'psqlparse',
#  'psutil',
#  'psycopg2',
#  'publicsuffix-list',
#  'pugixml',
#  'pulldown-cmark',
#  'pulumi',
#  'pupnp',
#  'py-serde',
#  'pyasn1-modules',
#  'pyasn1',
#  'pybind11',
#  'pycparser',
#  'pycrypto',
#  'pycryptodome',
#  'pydantic',
#  'pydateutil',
#  'pygments',
#  'pyjson5',
#  'pyjwt',
#  'pymysql',
#  'pynacl',
#  'pyodbc',
#  'pyparsing',
#  'pyrsistent',
#  'pytables',
#  'pytest-py',
#  'python-ecdsa',
#  'python-email-validator',
#  'python-fastjsonschema',
#  'python-future',
#  'python-graphviz',
#  'python-hyperlink',
#  'python-jose',
#  'python-lz4',
#  'python-markdown',
#  'python-markdownify',
#  'python-multipart',
#  'python-nameparser',
#  'python-nvd3',
#  'python-pathspec',
#  'python-phonenumbers',
#  'python-prompt-toolkit',
#  'python-pypdf',
#  'python-rison',
#  'python-rsa',
#  'python-tabulate',
#  'python3-libraries',
#  'python3-openid',
#  'pytz',
#  'pyvex',
#  'pyxdg',
#  'pyyaml',
#  'pyzmq',
#  'qcms',
#  'qdox',
#  'qemu',
#  'qpdf',
#  'qpid-proton',
#  'qs',
#  'qt',
#  'quantlib',
#  'quartz',
#  'qubes-os',
#  'quic-go',
#  'quiche',
#  'quick-xml',
#  'quickjs',
#  'rabbitmq-c',
#  'racket']

# %% [markdown]
# ## Requirement 2
#
# > API to retrieve details for a specific project (e.g., language, build system, fuzzer engines used).
#
# **Design Decision: Details Extraction**
#
# Most of the project details live in `project.yaml`, so it made sense to start by fetching it. I used GitHub's REST API for this too. The structured nature of the file made it easy to load into a `dataclass`. I introduced two modules for this: `loaders.py` and `models.py`. Even though the codebase is compact, I decided to break the functionality into separate modules early on, to strenghen decoupling and support modularity right off the bat.
#
# The build system, however, wasn't in `project.yaml`. For this, we had to fetch `build.sh` and parse it to try to deduce the build system. I did this with a simple heuristic that looks for mentions of certain build tools. I limited myself to the build tools mentioned by David and Adam in [this article](https://adalogics.com/blog/fuzzing-100-open-source-projects-with-oss-fuzz). The heuristic needs to be fleshed out; at this point, it's just a proof of concept.

# %%
# Get a specific project and show all its details
pp(ossfuzz.get_project("angular"))
# Out:
# Project(name='angular',
#         language='javascript',
#         homepage='https://angular.io/',
#         main_repo='https://github.com/angular/angular.git',
#         primary_contact=None,
#         vendor_ccs=['wagner@code-intelligence.com',
#                     'yakdan@code-intelligence.com',
#                     'patrice.salathe@code-intelligence.com',
#                     'hlin@code-intelligence.com',
#                     'christopher.krah@code-intelligence.com',
#                     'bug-disclosure@code-intelligence.com'],
#         fuzzing_engines=['libfuzzer'],
#         build_system='bazel')

# %%
# Get a specific project and show a specific detail, such as its language...
ossfuzz.get_project("curl").language
# Out:
# 'c++'

# %%
# ... or its build system...
ossfuzz.get_project("angular").build_system
# Out:
# 'bazel'

# %%
# ... or its fuzzing engines
ossfuzz.get_project("ada-url").fuzzing_engines
# Out:
# ['libfuzzer', 'afl', 'honggfuzz', 'centipede']

# %%
# We may also output details in json
print(ossfuzz.get_project("envoy").to_json())
# Out:
# {
#     "name": "envoy",
#     "language": "c++",
#     "homepage": "https://www.envoyproxy.io/",
#     "main_repo": "https://github.com/envoyproxy/envoy.git",
#     "primary_contact": "htuch@google.com",
#     "vendor_ccs": null,
#     "fuzzing_engines": [
#         "libfuzzer",
#         "honggfuzz"
#     ],
#     "build_system": "make"
# }

# %% [markdown]
# **Design Decision: Big Data Source**
#
# To get the details of a single project, GitHub's REST API does the job. Most notably, below 60 requests per hour, it doesn't require authentication, which is convenient for this demo. **But what if we want the details of all projects?** One request gets us one file. We need two files per project, and there are over 1000 projects. Even authenticated, we're bound to hit the rate limit of GitHub's REST API.
#
# Fortunately, GitHub offers an API for "big data": their GraphQL API. The queries are a bit verbose, but this API allows to bulk fetch all 2000+ files in a dozen queries. Technically, it could just be a single query, but I implemented rudimentary query batching for robustness.
#
# There's a **drawback**: the GraphQL API does require authentication by default. This entails creating a token in your GitHub account. You don't need to do for this demo to work, but a general user would need to do the following:
#
# > 1. Go to: **Settings > Developer settings > Personal access tokens > Fine-grained tokens > Generate new token**.
# > 2. Create a `.env` file at the root of the project and add the token as follows: `GITHUB_TOKEN=<your-personal-github-token>`.
#
# **Design Decision: Data Caching**
#
# While the GraphQL API is powerful, it isn't instant (the same can be said of any other method for sourcing the data). Getting all those files takes 30-60s. Naturally, we don't want to have to wait repeatedly. So the data is fetched once and cached. Then, we can refresh it at will.
#
# In terms of code, we implemented the cache as a dedicated class in its own module. It's bare at this point, but having it in a separate module from the get-go will make it easy to expand and inject inject into the relevant modules.
#
# **Design Decision: Project Structure**
#
# One thing to note is that our prototype has a flat structure, with all files in a single directory. As the project grows, we may want to adopt a more package-like structure and instance-based implementation. Our functionality could be wrapped into classes (e.g. App or Api), which would facilitate testing. Our decision to split the logic into modules early on would make this sort of transition easier.

# %%
# Cache all projects
ossfuzz.cache_projects()
# Out:
# Please wait: caching project data... (~45s, just once)
#  - build.sh files cached...
#  - proyect.yaml files cached...
# Done

# %%
# Get all projects and show their details (triggers caching if none found)
pp(ossfuzz.get_projects())
# Out:
# {'abseil-cpp': Project(name='abseil-cpp',
#                        language='c++',
#                        homepage='abseil.io',
#                        main_repo='https://github.com/abseil/abseil-cpp.git',
#                        primary_contact='dmauro@google.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=None,
#                        build_system='bazel'),
#  'abseil-py': Project(name='abseil-py',
#                       language='python',
#                       homepage='https://github.com/abseil/abseil-py',
#                       main_repo='https://github.com/abseil/abseil-py',
#                       primary_contact=None,
#                       vendor_ccs=['david@adalogics.com'],
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'ada-url': Project(name='ada-url',
#                     language='c++',
#                     homepage='https://ada-url.github.io/ada',
#                     main_repo='https://github.com/ada-url/ada.git',
#                     primary_contact='yagiz@nizipli.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer',
#                                      'afl',
#                                      'honggfuzz',
#                                      'centipede'],
#                     build_system=None),
#  'adal': Project(name='adal',
#                  language='python',
#                  homepage='https://github.com/AzureAD/azure-activedirectory-library-for-python',
#                  main_repo='https://github.com/AzureAD/azure-activedirectory-library-for-python',
#                  primary_contact=None,
#                  vendor_ccs=['david@adalogics.com',
#                              'adam@adalogics.com',
#                              'arthur.chan@adalogics.com'],
#                  fuzzing_engines=['libfuzzer'],
#                  build_system='unknown'),
#  'aiohttp': Project(name='aiohttp',
#                     language='python',
#                     homepage='https://github.com/aio-libs/aiohttp',
#                     main_repo='https://github.com/aio-libs/aiohttp',
#                     primary_contact=None,
#                     vendor_ccs=['david@adalogics.com', 'adam@adalogics.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='make'),
#  'airflow': Project(name='airflow',
#                     language='python',
#                     homepage='https://github.com/apache/airflow',
#                     main_repo='https://github.com/apache/airflow',
#                     primary_contact=None,
#                     vendor_ccs=['david@adalogics.com',
#                                 'adam@adalogics.com',
#                                 'arthur.chan@adalogics.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'alembic': Project(name='alembic',
#                     language='c++',
#                     homepage='https://github.com/alembic/alembic',
#                     main_repo='https://github.com/alembic/alembic',
#                     primary_contact='miller.lucas@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=None,
#                     build_system='cmake'),
#  'ampproject': Project(name='ampproject',
#                        language='c++',
#                        homepage='https://github.com/ampproject/amphtml',
#                        main_repo='https://github.com/ampproject/amphtml',
#                        primary_contact=None,
#                        vendor_ccs=['david@adalogics.com'],
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='bazel'),
#  'angular': Project(name='angular',
#                     language='javascript',
#                     homepage='https://angular.io/',
#                     main_repo='https://github.com/angular/angular.git',
#                     primary_contact=None,
#                     vendor_ccs=['wagner@code-intelligence.com',
#                                 'yakdan@code-intelligence.com',
#                                 'patrice.salathe@code-intelligence.com',
#                                 'hlin@code-intelligence.com',
#                                 'christopher.krah@code-intelligence.com',
#                                 'bug-disclosure@code-intelligence.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='bazel'),
#  'angus-mail': Project(name='angus-mail',
#                        language='jvm',
#                        homepage='https://eclipse-ee4j.github.io/mail',
#                        main_repo='https://github.com/eclipse-ee4j/angus-mail.git',
#                        primary_contact='',
#                        vendor_ccs=['glendowne@code-intelligence.com',
#                                    'wagner@code-intelligence.com',
#                                    'patrice.salathe@code-intelligence.com',
#                                    'yakdan@code-intelligence.com',
#                                    'hlin@code-intelligence.com',
#                                    'bug-disclosure@code-intelligence.com'],
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='unknown'),
#  'aniso8601': Project(name='aniso8601',
#                       language='python',
#                       homepage='https://bitbucket.org/nielsenb/aniso8601',
#                       main_repo='https://bitbucket.org/nielsenb/aniso8601',
#                       primary_contact=None,
#                       vendor_ccs=['david@adalogics.com'],
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'ansible': Project(name='ansible',
#                     language='python',
#                     homepage='https://github.com/ansible/ansible',
#                     main_repo='https://github.com/ansible/ansible',
#                     primary_contact=None,
#                     vendor_ccs=['david@adalogics.com',
#                                 'adam@adalogics.com',
#                                 'arthur.chan@adalogics.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'antlr3-java': Project(name='antlr3-java',
#                         language='jvm',
#                         homepage='https://www.antlr.org',
#                         main_repo='https://github.com/antlr/antlr3.git',
#                         primary_contact=None,
#                         vendor_ccs=['david@adalogics.com',
#                                     'arthur.chan@adalogics.com'],
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'antlr4-java': Project(name='antlr4-java',
#                         language='jvm',
#                         homepage='https://www.antlr.org',
#                         main_repo='https://github.com/antlr/antlr4.git',
#                         primary_contact='terrence.parr@gmail.com',
#                         vendor_ccs=['wagner@code-intelligence.com',
#                                     'yakdan@code-intelligence.com',
#                                     'glendowne@code-intelligence.com',
#                                     'patrice.salathe@code-intelligence.com',
#                                     'hlin@code-intelligence.com',
#                                     'bug-disclosure@code-intelligence.com'],
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'apache-axis2': Project(name='apache-axis2',
#                          language='jvm',
#                          homepage='https://axis.apache.org/axis2/java/core/',
#                          main_repo='https://github.com/apache/axis-axis2-java-core.git',
#                          primary_contact=None,
#                          vendor_ccs=['wagner@code-intelligence.com',
#                                      'yakdan@code-intelligence.com',
#                                      'glendowne@code-intelligence.com',
#                                      'patrice.salathe@code-intelligence.com',
#                                      'hlin@code-intelligence.com',
#                                      'schaich@code-intelligence.com',
#                                      'bug-disclosure@code-intelligence.com'],
#                          fuzzing_engines=['libfuzzer'],
#                          build_system='unknown'),
#  'apache-commons-bcel': Project(name='apache-commons-bcel',
#                                 language='jvm',
#                                 homepage='https://commons.apache.org/proper/commons-bcel/',
#                                 main_repo='https://github.com/apache/commons-bcel.git',
#                                 primary_contact='fuzz-testing@commons.apache.org',
#                                 vendor_ccs=['wagner@code-intelligence.com',
#                                             'yakdan@code-intelligence.com',
#                                             'glendowne@code-intelligence.com',
#                                             'patrice.salathe@code-intelligence.com',
#                                             'hlin@code-intelligence.com',
#                                             'schaich@code-intelligence.com',
#                                             'jacek.trossen@code-intelligence.com',
#                                             'bug-disclosure@code-intelligence.com'],
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='unknown'),
#  'apache-commons-beanutils': Project(name='apache-commons-beanutils',
#                                      language='jvm',
#                                      homepage='https://commons.apache.org/proper/commons-beanutils/',
#                                      main_repo='https://github.com/apache/commons-beanutils.git',
#                                      primary_contact='fuzz-testing@commons.apache.org',
#                                      vendor_ccs=['wagner@code-intelligence.com',
#                                                  'yakdan@code-intelligence.com',
#                                                  'glendowne@code-intelligence.com',
#                                                  'patrice.salathe@code-intelligence.com',
#                                                  'hlin@code-intelligence.com',
#                                                  'schaich@code-intelligence.com',
#                                                  'jacek.trossen@code-intelligence.com',
#                                                  'bug-disclosure@code-intelligence.com'],
#                                      fuzzing_engines=['libfuzzer'],
#                                      build_system='unknown'),
#  'apache-commons-cli': Project(name='apache-commons-cli',
#                                language='jvm',
#                                homepage='https://commons.apache.org/proper/commons-cli/',
#                                main_repo='https://github.com/apache/commons-cli.git',
#                                primary_contact='fuzz-testing@commons.apache.org',
#                                vendor_ccs=['wagner@code-intelligence.com',
#                                            'yakdan@code-intelligence.com',
#                                            'glendowne@code-intelligence.com',
#                                            'patrice.salathe@code-intelligence.com',
#                                            'hlin@code-intelligence.com',
#                                            'schaich@code-intelligence.com',
#                                            'jacek.trossen@code-intelligence.com',
#                                            'bug-disclosure@code-intelligence.com'],
#                                fuzzing_engines=['libfuzzer'],
#                                build_system='unknown'),
#  'apache-commons-codec': Project(name='apache-commons-codec',
#                                  language='jvm',
#                                  homepage='https://commons.apache.org/proper/commons-codec/',
#                                  main_repo='https://gitbox.apache.org/repos/asf/commons-codec.git',
#                                  primary_contact='fuzz-testing@commons.apache.org',
#                                  vendor_ccs=['wagner@code-intelligence.com',
#                                              'yakdan@code-intelligence.com',
#                                              'glendowne@code-intelligence.com',
#                                              'patrice.salathe@code-intelligence.com',
#                                              'hlin@code-intelligence.com',
#                                              'schaich@code-intelligence.com',
#                                              'jacek.trossen@code-intelligence.com',
#                                              'bug-disclosure@code-intelligence.com',
#                                              'david@adalogics.com',
#                                              'adam@adalogics.com',
#                                              'arthur.chan@adalogics.com'],
#                                  fuzzing_engines=['libfuzzer'],
#                                  build_system='unknown'),
#  'apache-commons-collections': Project(name='apache-commons-collections',
#                                        language='jvm',
#                                        homepage='https://commons.apache.org/proper/commons-collections/',
#                                        main_repo='https://github.com/apache/commons-collections.git',
#                                        primary_contact='fuzz-testing@commons.apache.org',
#                                        vendor_ccs=['wagner@code-intelligence.com',
#                                                    'yakdan@code-intelligence.com',
#                                                    'glendowne@code-intelligence.com',
#                                                    'patrice.salathe@code-intelligence.com',
#                                                    'hlin@code-intelligence.com',
#                                                    'schaich@code-intelligence.com',
#                                                    'jacek.trossen@code-intelligence.com',
#                                                    'bug-disclosure@code-intelligence.com'],
#                                        fuzzing_engines=['libfuzzer'],
#                                        build_system='unknown'),
#  'apache-commons-compress': Project(name='apache-commons-compress',
#                                     language='jvm',
#                                     homepage='https://commons.apache.org',
#                                     main_repo='https://github.com/apache/commons-compress',
#                                     primary_contact='fuzz-testing@commons.apache.org',
#                                     vendor_ccs=['wagner@code-intelligence.com',
#                                                 'yakdan@code-intelligence.com',
#                                                 'glendowne@code-intelligence.com',
#                                                 'patrice.salathe@code-intelligence.com',
#                                                 'hlin@code-intelligence.com',
#                                                 'jacek.trossen@code-intelligence.com',
#                                                 'schaich@code-intelligence.com',
#                                                 'norbert.schneider@code-intelligence.com',
#                                                 'bug-disclosure@code-intelligence.com'],
#                                     fuzzing_engines=['libfuzzer'],
#                                     build_system='unknown'),
#  'apache-commons-configuration': Project(name='apache-commons-configuration',
#                                          language='jvm',
#                                          homepage='https://commons.apache.org/proper/commons-configuration/',
#                                          main_repo='https://gitbox.apache.org/repos/asf/commons-configuration.git',
#                                          primary_contact='fuzz-testing@commons.apache.org',
#                                          vendor_ccs=['wagner@code-intelligence.com',
#                                                      'yakdan@code-intelligence.com',
#                                                      'glendowne@code-intelligence.com',
#                                                      'patrice.salathe@code-intelligence.com',
#                                                      'hlin@code-intelligence.com',
#                                                      'schaich@code-intelligence.com',
#                                                      'jacek.trossen@code-intelligence.com',
#                                                      'bug-disclosure@code-intelligence.com',
#                                                      'yoshi.weber@gmail.com'],
#                                          fuzzing_engines=['libfuzzer'],
#                                          build_system='make'),
#  'apache-commons-csv': Project(name='apache-commons-csv',
#                                language='jvm',
#                                homepage='https://github.com/apache/commons-csv',
#                                main_repo='https://github.com/apache/commons-csv.git',
#                                primary_contact='fuzz-testing@commons.apache.org',
#                                vendor_ccs=['glendowne@code-intelligence.com',
#                                            'wagner@code-intelligence.com',
#                                            'patrice.salathe@code-intelligence.com',
#                                            'yakdan@code-intelligence.com',
#                                            'hlin@code-intelligence.com',
#                                            'jacek.trossen@code-intelligence.com',
#                                            'bug-disclosure@code-intelligence.com'],
#                                fuzzing_engines=['libfuzzer'],
#                                build_system='unknown'),
#  'apache-commons-fileupload': Project(name='apache-commons-fileupload',
#                                       language='jvm',
#                                       homepage='https://commons.apache.org/proper/commons-fileupload/',
#                                       main_repo='https://github.com/apache/commons-fileupload.git',
#                                       primary_contact='fuzz-testing@commons.apache.org',
#                                       vendor_ccs=['wagner@code-intelligence.com',
#                                                   'yakdan@code-intelligence.com',
#                                                   'glendowne@code-intelligence.com',
#                                                   'patrice.salathe@code-intelligence.com',
#                                                   'hlin@code-intelligence.com',
#                                                   'schaich@code-intelligence.com',
#                                                   'jacek.trossen@code-intelligence.com',
#                                                   'bug-disclosure@code-intelligence.com'],
#                                       fuzzing_engines=['libfuzzer'],
#                                       build_system='unknown'),
#  'apache-commons-geometry': Project(name='apache-commons-geometry',
#                                     language='jvm',
#                                     homepage='https://commons.apache.org',
#                                     main_repo='https://github.com/apache/commons-geometry',
#                                     primary_contact='fuzz-testing@commons.apache.org',
#                                     vendor_ccs=['wagner@code-intelligence.com',
#                                                 'yakdan@code-intelligence.com',
#                                                 'glendowne@code-intelligence.com',
#                                                 'patrice.salathe@code-intelligence.com',
#                                                 'hlin@code-intelligence.com',
#                                                 'jacek.trossen@code-intelligence.com',
#                                                 'schaich@code-intelligence.com',
#                                                 'norbert.schneider@code-intelligence.com',
#                                                 'bug-disclosure@code-intelligence.com'],
#                                     fuzzing_engines=['libfuzzer'],
#                                     build_system='unknown'),
#  'apache-commons-imaging': Project(name='apache-commons-imaging',
#                                    language='jvm',
#                                    homepage='https://commons.apache.org',
#                                    main_repo='https://github.com/apache/commons-imaging',
#                                    primary_contact='fuzz-testing@commons.apache.org',
#                                    vendor_ccs=['wagner@code-intelligence.com',
#                                                'yakdan@code-intelligence.com',
#                                                'glendowne@code-intelligence.com',
#                                                'patrice.salathe@code-intelligence.com',
#                                                'hlin@code-intelligence.com',
#                                                'jacek.trossen@code-intelligence.com',
#                                                'schaich@code-intelligence.com',
#                                                'norbert.schneider@code-intelligence.com',
#                                                'bug-disclosure@code-intelligence.com',
#                                                'ggregory@apache.org',
#                                                'garydgregory@gmail.com'],
#                                    fuzzing_engines=['libfuzzer'],
#                                    build_system='unknown'),
#  'apache-commons-io': Project(name='apache-commons-io',
#                               language='jvm',
#                               homepage='https://commons.apache.org/proper/commons-io/',
#                               main_repo='https://gitbox.apache.org/repos/asf/commons-io.git',
#                               primary_contact='fuzz-testing@commons.apache.org',
#                               vendor_ccs=['wagner@code-intelligence.com',
#                                           'yakdan@code-intelligence.com',
#                                           'glendowne@code-intelligence.com',
#                                           'patrice.salathe@code-intelligence.com',
#                                           'hlin@code-intelligence.com',
#                                           'schaich@code-intelligence.com',
#                                           'jacek.trossen@code-intelligence.com',
#                                           'bug-disclosure@code-intelligence.com',
#                                           'david@adalogics.com',
#                                           'adam@adalogics.com',
#                                           'arthur.chan@adalogics.com'],
#                               fuzzing_engines=['libfuzzer'],
#                               build_system='unknown'),
#  'apache-commons-jxpath': Project(name='apache-commons-jxpath',
#                                   language='jvm',
#                                   homepage='https://github.com/apache/commons-jxpath.git',
#                                   main_repo='https://github.com/apache/commons-jxpath.git',
#                                   primary_contact='fuzz-testing@commons.apache.org',
#                                   vendor_ccs=['wagner@code-intelligence.com',
#                                               'yakdan@code-intelligence.com',
#                                               'glendowne@code-intelligence.com',
#                                               'patrice.salathe@code-intelligence.com',
#                                               'hlin@code-intelligence.com',
#                                               'schaich@code-intelligence.com',
#                                               'jacek.trossen@code-intelligence.com',
#                                               'bug-disclosure@code-intelligence.com'],
#                                   fuzzing_engines=['libfuzzer'],
#                                   build_system='unknown'),
#  'apache-commons-lang': Project(name='apache-commons-lang',
#                                 language='jvm',
#                                 homepage='https://github.com/apache/commons-lang',
#                                 main_repo='https://github.com/apache/commons-lang.git',
#                                 primary_contact='fuzz-testing@commons.apache.org',
#                                 vendor_ccs=['wagner@code-intelligence.com',
#                                             'yakdan@code-intelligence.com',
#                                             'glendowne@code-intelligence.com',
#                                             'patrice.salathe@code-intelligence.com',
#                                             'hlin@code-intelligence.com',
#                                             'schaich@code-intelligence.com',
#                                             'jacek.trossen@code-intelligence.com',
#                                             'bug-disclosure@code-intelligence.com',
#                                             'david@adalogics.com',
#                                             'adam@adalogics.com',
#                                             'arthur.chan@adalogics.com'],
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='unknown'),
#  'apache-commons-logging': Project(name='apache-commons-logging',
#                                    language='jvm',
#                                    homepage='https://commons.apache.org/proper/commons-collections/',
#                                    main_repo='https://gitbox.apache.org/repos/asf/commons-logging.git',
#                                    primary_contact='fuzz-testing@commons.apache.org',
#                                    vendor_ccs=['wagner@code-intelligence.com',
#                                                'yakdan@code-intelligence.com',
#                                                'glendowne@code-intelligence.com',
#                                                'patrice.salathe@code-intelligence.com',
#                                                'hlin@code-intelligence.com',
#                                                'schaich@code-intelligence.com',
#                                                'jacek.trossen@code-intelligence.com',
#                                                'bug-disclosure@code-intelligence.com'],
#                                    fuzzing_engines=['libfuzzer'],
#                                    build_system='unknown'),
#  'apache-commons-math': Project(name='apache-commons-math',
#                                 language='jvm',
#                                 homepage='https://commons.apache.org',
#                                 main_repo='https://github.com/apache/commons-math',
#                                 primary_contact='fuzz-testing@commons.apache.org',
#                                 vendor_ccs=['wagner@code-intelligence.com',
#                                             'yakdan@code-intelligence.com',
#                                             'glendowne@code-intelligence.com',
#                                             'patrice.salathe@code-intelligence.com',
#                                             'hlin@code-intelligence.com',
#                                             'jacek.trossen@code-intelligence.com',
#                                             'schaich@code-intelligence.com',
#                                             'norbert.schneider@code-intelligence.com',
#                                             'bug-disclosure@code-intelligence.com'],
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='unknown'),
#  'apache-commons-net': Project(name='apache-commons-net',
#                                language='jvm',
#                                homepage='https://github.com/apache/commons-net',
#                                main_repo='https://github.com/apache/commons-net.git',
#                                primary_contact='fuzz-testing@commons.apache.org',
#                                vendor_ccs=None,
#                                fuzzing_engines=['libfuzzer'],
#                                build_system='unknown'),
#  'apache-commons-text': Project(name='apache-commons-text',
#                                 language='jvm',
#                                 homepage='https://github.com/apache/commons-text/',
#                                 main_repo='https://github.com/apache/commons-text/',
#                                 primary_contact='fuzz-testing@commons.apache.org',
#                                 vendor_ccs=['michael.nothhard@code-intelligence.com',
#                                             'glendowne@code-intelligence.com',
#                                             'wagner@code-intelligence.com',
#                                             'patrice.salathe@code-intelligence.com',
#                                             'yakdan@code-intelligence.com',
#                                             'hlin@code-intelligence.com',
#                                             'jacek.trossen@code-intelligence.com',
#                                             'bug-disclosure@code-intelligence.com'],
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='unknown'),
#  'apache-commons-validator': Project(name='apache-commons-validator',
#                                      language='jvm',
#                                      homepage='https://github.com/apache/commons-validator',
#                                      main_repo='https://github.com/apache/commons-validator.git',
#                                      primary_contact='fuzz-testing@commons.apache.org',
#                                      vendor_ccs=None,
#                                      fuzzing_engines=['libfuzzer'],
#                                      build_system='unknown'),
#  'apache-cxf': Project(name='apache-cxf',
#                        language='jvm',
#                        homepage='https://cxf.apache.org/',
#                        main_repo='https://github.com/apache/cxf/',
#                        primary_contact=None,
#                        vendor_ccs=['wagner@code-intelligence.com',
#                                    'yakdan@code-intelligence.com',
#                                    'glendowne@code-intelligence.com',
#                                    'patrice.salathe@code-intelligence.com',
#                                    'hlin@code-intelligence.com',
#                                    'bug-disclosure@code-intelligence.com'],
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='unknown'),
#  'apache-doris': Project(name='apache-doris',
#                          language='c++',
#                          homepage='https://doris.apache.org',
#                          main_repo='https://github.com/apache/doris.git',
#                          primary_contact='dataroaring@gmail.com',
#                          vendor_ccs=None,
#                          fuzzing_engines=None,
#                          build_system=None),
#  'apache-felix-dev': Project(name='apache-felix-dev',
#                              language='jvm',
#                              homepage='https://felix.apache.org/',
#                              main_repo='https://github.com/apache/felix-dev.git',
#                              primary_contact=None,
#                              vendor_ccs=['wagner@code-intelligence.com',
#                                          'yakdan@code-intelligence.com',
#                                          'glendowne@code-intelligence.com',
#                                          'patrice.salathe@code-intelligence.com',
#                                          'hlin@code-intelligence.com',
#                                          'jacek.trossen@code-intelligence.com',
#                                          'bug-disclosure@code-intelligence.com'],
#                              fuzzing_engines=['libfuzzer'],
#                              build_system='unknown'),
#  'apache-httpd': Project(name='apache-httpd',
#                          language='c',
#                          homepage='https://httpd.apache.org/',
#                          main_repo='https://github.com/apache/httpd',
#                          primary_contact='david@adalogics.com',
#                          vendor_ccs=None,
#                          fuzzing_engines=None,
#                          build_system='make'),
#  'apache-logging-log4cxx': Project(name='apache-logging-log4cxx',
#                                    language='c++',
#                                    homepage='https://logging.apache.org/log4cxx',
#                                    main_repo='https://github.com/apache/logging-log4cxx',
#                                    primary_contact='volkan@yazi.ci',
#                                    vendor_ccs=None,
#                                    fuzzing_engines=['afl',
#                                                     'honggfuzz',
#                                                     'libfuzzer',
#                                                     'centipede'],
#                                    build_system='unknown'),
#  'apache-poi': Project(name='apache-poi',
#                        language='jvm',
#                        homepage='https://poi.apache.org/',
#                        main_repo='https://github.com/apache/poi.git',
#                        primary_contact=None,
#                        vendor_ccs=['wagner@code-intelligence.com',
#                                    'yakdan@code-intelligence.com',
#                                    'glendowne@code-intelligence.com',
#                                    'patrice.salathe@code-intelligence.com',
#                                    'hlin@code-intelligence.com',
#                                    'schaich@code-intelligence.com',
#                                    'bug-disclosure@code-intelligence.com',
#                                    'centic@apache.org',
#                                    'dominik.stadler@gmail.com'],
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='unknown'),
#  'aptos-core': Project(name='aptos-core',
#                        language='rust',
#                        homepage='https://aptos.dev',
#                        main_repo='https://github.com/aptos-labs/aptos-core',
#                        primary_contact='gerardo@aptoslabs.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='unknown'),
#  'archaius-core': Project(name='archaius-core',
#                           language='jvm',
#                           homepage='https://github.com/Netflix/archaius',
#                           main_repo='https://github.com/Netflix/archaius.git',
#                           primary_contact=None,
#                           vendor_ccs=['wagner@code-intelligence.com',
#                                       'yakdan@code-intelligence.com',
#                                       'glendowne@code-intelligence.com',
#                                       'patrice.salathe@code-intelligence.com',
#                                       'hlin@code-intelligence.com',
#                                       'bug-disclosure@code-intelligence.com'],
#                           fuzzing_engines=['libfuzzer'],
#                           build_system='unknown'),
#  'arduinojson': Project(name='arduinojson',
#                         language='c++',
#                         homepage='https://github.com/bblanchon/ArduinoJson',
#                         main_repo='https://github.com/bblanchon/ArduinoJson.git',
#                         primary_contact='benoit.blanchon@gmail.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=None,
#                         build_system='make'),
#  'argcomplete': Project(name='argcomplete',
#                         language='python',
#                         homepage='https://github.com/kislyuk/argcomplete',
#                         main_repo='https://github.com/kislyuk/argcomplete',
#                         primary_contact=None,
#                         vendor_ccs=['david@adalogics.com'],
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'argo': Project(name='argo',
#                  language='go',
#                  homepage='https://argoproj.github.io/',
#                  main_repo='https://github.com/argoproj',
#                  primary_contact='terrytangyuan@gmail.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=['libfuzzer'],
#                  build_system='unknown'),
#  'args': Project(name='args',
#                  language='c++',
#                  homepage='https://taywee.github.io/args/',
#                  main_repo='https://github.com/Taywee/args',
#                  primary_contact='taylor@axfive.net',
#                  vendor_ccs=None,
#                  fuzzing_engines=None,
#                  build_system='cmake'),
#  'args4j': Project(name='args4j',
#                    language='jvm',
#                    homepage='https://github.com/kohsuke/args4j',
#                    main_repo='https://github.com/kohsuke/args4j',
#                    primary_contact=None,
#                    vendor_ccs=['bug-disclosure@code-intelligence.com'],
#                    fuzzing_engines=['libfuzzer'],
#                    build_system='unknown'),
#  'arrow': Project(name='arrow',
#                   language='c++',
#                   homepage='https://arrow.apache.org/',
#                   main_repo='https://github.com/apache/arrow.git',
#                   primary_contact='antoine@python.org',
#                   vendor_ccs=None,
#                   fuzzing_engines=None,
#                   build_system='cmake'),
#  'arrow-java': Project(name='arrow-java',
#                        language='jvm',
#                        homepage='https://arrow.apache.org/',
#                        main_repo='https://github.com/apache/arrow.git',
#                        primary_contact='liya.fan03@gmail.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='unknown'),
#  'arrow-py': Project(name='arrow-py',
#                      language='python',
#                      homepage='https://github.com/arrow-py/arrow',
#                      main_repo='https://github.com/arrow-py/arrow',
#                      primary_contact='me@krisfremen.com',
#                      vendor_ccs=['david@adalogics.com'],
#                      fuzzing_engines=['libfuzzer'],
#                      build_system='unknown'),
#  'askama': Project(name='askama',
#                    language='rust',
#                    homepage='https://askama.readthedocs.io/',
#                    main_repo='https://github.com/askama-rs/askama',
#                    primary_contact='rene.kijewski@fu-berlin.de',
#                    vendor_ccs=None,
#                    fuzzing_engines=['libfuzzer'],
#                    build_system='unknown'),
#  'asn1crypto': Project(name='asn1crypto',
#                        language='python',
#                        homepage='https://github.com/wbond/asn1crypto',
#                        main_repo='https://github.com/wbond/asn1crypto',
#                        primary_contact='will@wbond.net',
#                        vendor_ccs=['david@adalogics.com'],
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='unknown'),
#  'aspectj': Project(name='aspectj',
#                     language='jvm',
#                     homepage='https://www.eclipse.org/aspectj/',
#                     main_repo='https://github.com/eclipse/org.aspectj',
#                     primary_contact=None,
#                     vendor_ccs=['wagner@code-intelligence.com',
#                                 'yakdan@code-intelligence.com',
#                                 'glendowne@code-intelligence.com',
#                                 'patrice.salathe@code-intelligence.com',
#                                 'hlin@code-intelligence.com',
#                                 'schaich@code-intelligence.com',
#                                 'bug-disclosure@code-intelligence.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'aspell': Project(name='aspell',
#                    language='c++',
#                    homepage='https://github.com/GNUAspell/aspell',
#                    main_repo='https://github.com/gnuaspell/aspell.git',
#                    primary_contact='kevina@gnu.org',
#                    vendor_ccs=None,
#                    fuzzing_engines=None,
#                    build_system='unknown'),
#  'assimp': Project(name='assimp',
#                    language='c++',
#                    homepage='https://github.com/assimp/assimp',
#                    main_repo='https://github.com/assimp/assimp.git',
#                    primary_contact='kim.kulling@googlemail.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='cmake'),
#  'astc-encoder': Project(name='astc-encoder',
#                          language='c++',
#                          homepage='https://github.com/ARM-software/astc-encoder',
#                          main_repo='https://github.com/ARM-software/astc-encoder',
#                          primary_contact='peter.harris@arm.com',
#                          vendor_ccs=None,
#                          fuzzing_engines=None,
#                          build_system='unknown'),
#  'asteval': Project(name='asteval',
#                     language='python',
#                     homepage='https://github.com/newville/asteval',
#                     main_repo='https://github.com/newville/asteval',
#                     primary_contact=None,
#                     vendor_ccs=['david@adalogics.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'astro-compiler': Project(name='astro-compiler',
#                            language='go',
#                            homepage='https://github.com/withastro/compiler',
#                            main_repo='https://github.com/withastro/compiler',
#                            primary_contact='cable023@gmail.com',
#                            vendor_ccs=None,
#                            fuzzing_engines=['libfuzzer'],
#                            build_system='unknown'),
#  'astroid': Project(name='astroid',
#                     language='python',
#                     homepage='https://github.com/pylint-dev/astroid',
#                     main_repo='https://github.com/pylint-dev/astroid',
#                     primary_contact='jacobtylerwalls@gmail.com',
#                     vendor_ccs=['david@adalogics.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'asttokens': Project(name='asttokens',
#                       language='python',
#                       homepage='https://github.com/gristlabs/asttokens',
#                       main_repo='https://github.com/gristlabs/asttokens',
#                       primary_contact=None,
#                       vendor_ccs=['david@adalogics.com'],
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'async-http-client': Project(name='async-http-client',
#                               language='jvm',
#                               homepage='https://github.com/AsyncHttpClient/async-http-client/',
#                               main_repo='https://github.com/AsyncHttpClient/async-http-client/',
#                               primary_contact='aayush@shieldblaze.com',
#                               vendor_ccs=['wagner@code-intelligence.com',
#                                           'yakdan@code-intelligence.com',
#                                           'glendowne@code-intelligence.com',
#                                           'patrice.salathe@code-intelligence.com',
#                                           'hlin@code-intelligence.com',
#                                           'bug-disclosure@code-intelligence.com'],
#                               fuzzing_engines=['libfuzzer'],
#                               build_system='unknown'),
#  'atomic': Project(name='atomic',
#                    language='go',
#                    homepage='https://github.com/uber-go/atomic',
#                    main_repo='https://github.com/uber-go/atomic',
#                    primary_contact=None,
#                    vendor_ccs=None,
#                    fuzzing_engines=['libfuzzer'],
#                    build_system='unknown'),
#  'attrs': Project(name='attrs',
#                   language='python',
#                   homepage='https://www.attrs.org',
#                   main_repo='https://github.com/python-attrs/attrs.git',
#                   primary_contact=None,
#                   vendor_ccs=['sergesanspaille@free.fr'],
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='unknown'),
#  'augeas': Project(name='augeas',
#                    language='c++',
#                    homepage='https://github.com/hercules-team/augeas',
#                    main_repo='https://github.com/hercules-team/augeas',
#                    primary_contact='lutter@watzmann.net',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='make'),
#  'autoflake': Project(name='autoflake',
#                       language='python',
#                       homepage='https://www.github.com/PyCQA/autoflake',
#                       main_repo='https://www.github.com/PyCQA/autoflake',
#                       primary_contact=None,
#                       vendor_ccs=['david@adalogics.com'],
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'autopep8': Project(name='autopep8',
#                      language='python',
#                      homepage='https://github.com/hhatto/autopep8',
#                      main_repo='https://github.com/hhatto/autopep8',
#                      primary_contact=None,
#                      vendor_ccs=['david@adalogics.com'],
#                      fuzzing_engines=['libfuzzer'],
#                      build_system='unknown'),
#  'avahi': Project(name='avahi',
#                   language='c++',
#                   homepage='https://avahi.org/',
#                   main_repo='https://github.com/avahi/avahi',
#                   primary_contact='trent@lloyd.id.au',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='unknown'),
#  'avro': Project(name='avro',
#                  language='jvm',
#                  homepage='https://avro.apache.org/',
#                  main_repo='https://github.com/apache/avro',
#                  primary_contact='martin.grigorov@gmail.com',
#                  vendor_ccs=['wagner@code-intelligence.com',
#                              'yakdan@code-intelligence.com',
#                              'patrice.salathe@code-intelligence.com',
#                              'hlin@code-intelligence.com',
#                              'bug-disclosure@code-intelligence.com'],
#                  fuzzing_engines=['libfuzzer'],
#                  build_system='unknown'),
#  'azure-sdk-for-python': Project(name='azure-sdk-for-python',
#                                  language='python',
#                                  homepage='https://github.com/azure/azure-sdk-for-python',
# ...
#                        main_repo='https://github.com/lz4/lz4',
#                        primary_contact='jonathan.underwood@gmail.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='unknown'),
#  'python-markdown': Project(name='python-markdown',
#                             language='python',
#                             homepage='https://github.com/python-markdown/markdown',
#                             main_repo='https://github.com/python-markdown/markdown',
#                             primary_contact=None,
#                             vendor_ccs=['david@adalogics.com'],
#                             fuzzing_engines=['libfuzzer'],
#                             build_system='unknown'),
#  'python-markdownify': Project(name='python-markdownify',
#                                language='python',
#                                homepage='http://github.com/matthewwithanm/python-markdownify',
#                                main_repo='http://github.com/matthewwithanm/python-markdownify',
#                                primary_contact=None,
#                                vendor_ccs=['david@adalogics.com'],
#                                fuzzing_engines=['libfuzzer'],
#                                build_system='unknown'),
#  'python-multipart': Project(name='python-multipart',
#                              language='python',
#                              homepage='https://github.com/Kludex/python-multipart',
#                              main_repo='https://github.com/Kludex/python-multipart',
#                              primary_contact='marcelotryle@gmail.com',
#                              vendor_ccs=['maxnair.dev@gmail.com'],
#                              fuzzing_engines=['libfuzzer'],
#                              build_system='unknown'),
#  'python-nameparser': Project(name='python-nameparser',
#                               language='python',
#                               homepage='https://github.com/derek73/python-nameparser',
#                               main_repo='https://github.com/derek73/python-nameparser',
#                               primary_contact=None,
#                               vendor_ccs=['david@adalogics.com'],
#                               fuzzing_engines=['libfuzzer'],
#                               build_system='unknown'),
#  'python-nvd3': Project(name='python-nvd3',
#                         language='python',
#                         homepage='https://github.com/areski/python-nvd3',
#                         main_repo='https://github.com/areski/python-nvd3',
#                         primary_contact=None,
#                         vendor_ccs=['david@adalogics.com'],
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'python-pathspec': Project(name='python-pathspec',
#                             language='python',
#                             homepage='https://github.com/cpburnz/python-pathspec',
#                             main_repo='https://github.com/cpburnz/python-pathspec',
#                             primary_contact=None,
#                             vendor_ccs=['david@adalogics.com'],
#                             fuzzing_engines=['libfuzzer'],
#                             build_system='unknown'),
#  'python-phonenumbers': Project(name='python-phonenumbers',
#                                 language='python',
#                                 homepage='https://github.com/daviddrysdale/python-phonenumbers',
#                                 main_repo='https://github.com/daviddrysdale/python-phonenumbers.git',
#                                 primary_contact='rik@purpleguy.nl',
#                                 vendor_ccs=None,
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='unknown'),
#  'python-prompt-toolkit': Project(name='python-prompt-toolkit',
#                                   language='python',
#                                   homepage='https://github.com/prompt-toolkit/python-prompt-toolkit',
#                                   main_repo='https://github.com/prompt-toolkit/python-prompt-toolkit',
#                                   primary_contact=None,
#                                   vendor_ccs=['david@adalogics.com'],
#                                   fuzzing_engines=['libfuzzer'],
#                                   build_system='unknown'),
#  'python-pypdf': Project(name='python-pypdf',
#                          language='python',
#                          homepage='https://github.com/py-pdf/pypdf',
#                          main_repo='https://github.com/py-pdf/pypdf.git',
#                          primary_contact='info@martin-thoma.de',
#                          vendor_ccs=None,
#                          fuzzing_engines=['libfuzzer'],
#                          build_system='unknown'),
#  'python-rison': Project(name='python-rison',
#                          language='python',
#                          homepage='https://github.com/betodealmeida/python-rison',
#                          main_repo='https://github.com/betodealmeida/python-rison',
#                          primary_contact=None,
#                          vendor_ccs=['david@adalogics.com'],
#                          fuzzing_engines=['libfuzzer'],
#                          build_system='unknown'),
#  'python-rsa': Project(name='python-rsa',
#                        language='python',
#                        homepage='https://stuvel.eu/software/rsa/',
#                        main_repo='https://github.com/sybrenstuvel/python-rsa',
#                        primary_contact=None,
#                        vendor_ccs=['david@adalogics.com'],
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='unknown'),
#  'python-tabulate': Project(name='python-tabulate',
#                             language='python',
#                             homepage='https://github.com/astanin/python-tabulate',
#                             main_repo='https://github.com/astanin/python-tabulate',
#                             primary_contact='s.astanin@gmail.com',
#                             vendor_ccs=['david@adalogics.com',
#                                         'adam@adalogics.com'],
#                             fuzzing_engines=['libfuzzer'],
#                             build_system='unknown'),
#  'python3-libraries': Project(name='python3-libraries',
#                               language='c',
#                               homepage='https://www.python.org/',
#                               main_repo='https://github.com/python/cpython',
#                               primary_contact='seth@python.org',
#                               vendor_ccs=None,
#                               fuzzing_engines=['libfuzzer', 'honggfuzz'],
#                               build_system='make'),
#  'python3-openid': Project(name='python3-openid',
#                            language='python',
#                            homepage='https://github.com/necaris/python3-openid',
#                            main_repo='https://github.com/necaris/python3-openid',
#                            primary_contact=None,
#                            vendor_ccs=['david@adalogics.com'],
#                            fuzzing_engines=['libfuzzer'],
#                            build_system='unknown'),
#  'pytz': Project(name='pytz',
#                  language='python',
#                  homepage='https://github.com/stub42/pytz',
#                  main_repo='https://github.com/stub42/pytz',
#                  primary_contact=None,
#                  vendor_ccs=['david@adalogics.com',
#                              'adam@adalogics.com',
#                              'athur.chan@adalogics.com'],
#                  fuzzing_engines=['libfuzzer'],
#                  build_system='make'),
#  'pyvex': Project(name='pyvex',
#                   language='python',
#                   homepage='https://api.angr.io/projects/pyvex/en/latest/api.html',
#                   main_repo='https://github.com/angr/pyvex.git',
#                   primary_contact='angr-dev@asu.edu',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer'],
#                   build_system=None),
#  'pyxdg': Project(name='pyxdg',
#                   language='python',
#                   homepage='https://freedesktop.org/wiki/Software/pyxdg/',
#                   main_repo='https://github.com/takluyver/pyxdg',
#                   primary_contact=None,
#                   vendor_ccs=['david@adalogics.com'],
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='unknown'),
#  'pyyaml': Project(name='pyyaml',
#                    language='python',
#                    homepage='https://github.com/yaml/pyyaml',
#                    main_repo='https://github.com/yaml/pyyaml',
#                    primary_contact='pyyaml@yaml.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=['libfuzzer'],
#                    build_system='unknown'),
#  'pyzmq': Project(name='pyzmq',
#                   language='python',
#                   homepage='https://github.com/zeromq/pyzmq',
#                   main_repo='https://github.com/zeromq/pyzmq',
#                   primary_contact=None,
#                   vendor_ccs=['david@adalogics.com'],
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='unknown'),
#  'qcms': Project(name='qcms',
#                  language='rust',
#                  homepage='https://hg.mozilla.org/mozilla-central/file/tip/gfx/qcms/',
#                  main_repo=None,
#                  primary_contact='twsmith@mozilla.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=['libfuzzer'],
#                  build_system='unknown'),
#  'qdox': Project(name='qdox',
#                  language='jvm',
#                  homepage='https://github.com/paul-hammant/qdox/',
#                  main_repo='https://github.com/paul-hammant/qdox/',
#                  primary_contact=None,
#                  vendor_ccs=['wagner@code-intelligence.com',
#                              'yakdan@code-intelligence.com',
#                              'patrice.salathe@code-intelligence.com',
#                              'hlin@code-intelligence.com',
#                              'bug-disclosure@code-intelligence.com'],
#                  fuzzing_engines=['libfuzzer'],
#                  build_system='unknown'),
#  'qemu': Project(name='qemu',
#                  language='c',
#                  homepage='https://www.qemu.org/',
#                  main_repo='https://git.qemu.org/git/qemu.git',
#                  primary_contact='alxndr@bu.edu',
#                  vendor_ccs=None,
#                  fuzzing_engines=['libfuzzer'],
#                  build_system='unknown'),
#  'qpdf': Project(name='qpdf',
#                  language='c++',
#                  homepage='http://qpdf.sourceforge.net/',
#                  main_repo='https://github.com/qpdf/qpdf.git',
#                  primary_contact='qberkenbilt@gmail.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                  build_system='cmake'),
#  'qpid-proton': Project(name='qpid-proton',
#                         language='c++',
#                         homepage='https://qpid.apache.org/proton/',
#                         main_repo='https://github.com/apache/qpid-proton.git',
#                         primary_contact='jross@apache.org',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='cmake'),
#  'qs': Project(name='qs',
#                language='c++',
#                homepage='https://github.com/ljharb/qs',
#                main_repo='https://github.com/ljharb/qs.git',
#                primary_contact='ljharb@gmail.com',
#                vendor_ccs=None,
#                fuzzing_engines=None,
#                build_system=None),
#  'qt': Project(name='qt',
#                language='c++',
#                homepage='http://qt-project.org',
#                main_repo='git://code.qt.io/qt/qt5.git',
#                primary_contact='rlohningqt@gmail.com',
#                vendor_ccs=None,
#                fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                build_system=None),
#  'quantlib': Project(name='quantlib',
#                      language='c++',
#                      homepage='https://www.quantlib.org/',
#                      main_repo='https://github.com/lballabio/QuantLib.git',
#                      primary_contact='luigi.ballabio@gmail.com',
#                      vendor_ccs=None,
#                      fuzzing_engines=['libfuzzer', 'honggfuzz'],
#                      build_system='cmake'),
#  'quartz': Project(name='quartz',
#                    language='jvm',
#                    homepage='https://github.com/quartz-scheduler/quartz',
#                    main_repo='https://github.com/quartz-scheduler/quartz',
#                    primary_contact=None,
#                    vendor_ccs=['david@adalogics.com',
#                                'adam@adalogics.com',
#                                'arthur.chan@adalogics.com'],
#                    fuzzing_engines=['libfuzzer'],
#                    build_system='unknown'),
#  'qubes-os': Project(name='qubes-os',
#                      language='c++',
#                      homepage='https://www.qubes-os.org/',
#                      main_repo='https://github.com/QubesOS',
#                      primary_contact='jpo@vt.edu',
#                      vendor_ccs=None,
#                      fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                      build_system='make'),
#  'quic-go': Project(name='quic-go',
#                     language='go',
#                     homepage='https://github.com/quic-go/quic-go',
#                     main_repo='https://github.com/quic-go/quic-go',
#                     primary_contact='martenseemann@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer'],
#                     build_system=None),
#  'quiche': Project(name='quiche',
#                    language='c++',
#                    homepage='https://github.com/google/quiche',
#                    main_repo='https://github.com/google/quiche',
#                    primary_contact=None,
#                    vendor_ccs=['david@adalogics.com'],
#                    fuzzing_engines=['libfuzzer'],
#                    build_system='bazel'),
#  'quick-xml': Project(name='quick-xml',
#                       language='rust',
#                       homepage='https://github.com/tafia/quick-xml',
#                       main_repo='https://github.com/tafia/quick-xml',
#                       primary_contact='tafia973@gmail.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'quickjs': Project(name='quickjs',
#                     language='c',
#                     homepage='https://bellard.org/quickjs/',
#                     main_repo='https://github.com/bellard/quickjs',
#                     primary_contact='fabrice.bellard@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'rabbitmq-c': Project(name='rabbitmq-c',
#                        language='c',
#                        homepage='https://github.com/alanxz/rabbitmq-c',
#                        main_repo='https://github.com/alanxz/rabbitmq-c',
#                        primary_contact='alan.antonuk@gmail.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                        build_system='cmake'),
#  'racket': Project(name='racket',
#                    language=None,
#                    homepage='https://racket-lang.org',
#                    main_repo='https://github.com/racket/racket/',
#                    primary_contact='pocmatos@gmail.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=None,
#                    build_system=None)}

# %% [markdown]
# ## Requirement 3
#
# > Ability to filter projects based on criteria (e.g., language, library).
#
# **Design Decision: Basic Filtering**
#
# Now that we have 1000+ projects cache, we want to be able to search through them. A simple way of doing this is via keyword search. I implementing the functionality as a function that allows users to supply values for project attributes (name, language, etc.). Currently, it returns the projects whose attributes include those keywords (including partial matches).
#
# The implementation uses a closure to build a predicate that is then passed to a filtering function for matching. It's a bit more abstract, but in my opinion, it makes for clean, Pythonic code. Eventually, we could adopt a full-fledged specification pattern, allowing more flexible and granular matching with IF, AND, OR, etc.

# %%
# Get all projects whose attrs contain specific keywords
pp(ossfuzz.match_projects(
    language="c++",
))
# Out:
# {'abseil-cpp': Project(name='abseil-cpp',
#                        language='c++',
#                        homepage='abseil.io',
#                        main_repo='https://github.com/abseil/abseil-cpp.git',
#                        primary_contact='dmauro@google.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=None,
#                        build_system='bazel'),
#  'ada-url': Project(name='ada-url',
#                     language='c++',
#                     homepage='https://ada-url.github.io/ada',
#                     main_repo='https://github.com/ada-url/ada.git',
#                     primary_contact='yagiz@nizipli.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer',
#                                      'afl',
#                                      'honggfuzz',
#                                      'centipede'],
#                     build_system=None),
#  'alembic': Project(name='alembic',
#                     language='c++',
#                     homepage='https://github.com/alembic/alembic',
#                     main_repo='https://github.com/alembic/alembic',
#                     primary_contact='miller.lucas@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=None,
#                     build_system='cmake'),
#  'ampproject': Project(name='ampproject',
#                        language='c++',
#                        homepage='https://github.com/ampproject/amphtml',
#                        main_repo='https://github.com/ampproject/amphtml',
#                        primary_contact=None,
#                        vendor_ccs=['david@adalogics.com'],
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='bazel'),
#  'apache-doris': Project(name='apache-doris',
#                          language='c++',
#                          homepage='https://doris.apache.org',
#                          main_repo='https://github.com/apache/doris.git',
#                          primary_contact='dataroaring@gmail.com',
#                          vendor_ccs=None,
#                          fuzzing_engines=None,
#                          build_system=None),
#  'apache-logging-log4cxx': Project(name='apache-logging-log4cxx',
#                                    language='c++',
#                                    homepage='https://logging.apache.org/log4cxx',
#                                    main_repo='https://github.com/apache/logging-log4cxx',
#                                    primary_contact='volkan@yazi.ci',
#                                    vendor_ccs=None,
#                                    fuzzing_engines=['afl',
#                                                     'honggfuzz',
#                                                     'libfuzzer',
#                                                     'centipede'],
#                                    build_system='unknown'),
#  'arduinojson': Project(name='arduinojson',
#                         language='c++',
#                         homepage='https://github.com/bblanchon/ArduinoJson',
#                         main_repo='https://github.com/bblanchon/ArduinoJson.git',
#                         primary_contact='benoit.blanchon@gmail.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=None,
#                         build_system='make'),
#  'args': Project(name='args',
#                  language='c++',
#                  homepage='https://taywee.github.io/args/',
#                  main_repo='https://github.com/Taywee/args',
#                  primary_contact='taylor@axfive.net',
#                  vendor_ccs=None,
#                  fuzzing_engines=None,
#                  build_system='cmake'),
#  'arrow': Project(name='arrow',
#                   language='c++',
#                   homepage='https://arrow.apache.org/',
#                   main_repo='https://github.com/apache/arrow.git',
#                   primary_contact='antoine@python.org',
#                   vendor_ccs=None,
#                   fuzzing_engines=None,
#                   build_system='cmake'),
#  'aspell': Project(name='aspell',
#                    language='c++',
#                    homepage='https://github.com/GNUAspell/aspell',
#                    main_repo='https://github.com/gnuaspell/aspell.git',
#                    primary_contact='kevina@gnu.org',
#                    vendor_ccs=None,
#                    fuzzing_engines=None,
#                    build_system='unknown'),
#  'assimp': Project(name='assimp',
#                    language='c++',
#                    homepage='https://github.com/assimp/assimp',
#                    main_repo='https://github.com/assimp/assimp.git',
#                    primary_contact='kim.kulling@googlemail.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='cmake'),
#  'astc-encoder': Project(name='astc-encoder',
#                          language='c++',
#                          homepage='https://github.com/ARM-software/astc-encoder',
#                          main_repo='https://github.com/ARM-software/astc-encoder',
#                          primary_contact='peter.harris@arm.com',
#                          vendor_ccs=None,
#                          fuzzing_engines=None,
#                          build_system='unknown'),
#  'augeas': Project(name='augeas',
#                    language='c++',
#                    homepage='https://github.com/hercules-team/augeas',
#                    main_repo='https://github.com/hercules-team/augeas',
#                    primary_contact='lutter@watzmann.net',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='make'),
#  'avahi': Project(name='avahi',
#                   language='c++',
#                   homepage='https://avahi.org/',
#                   main_repo='https://github.com/avahi/avahi',
#                   primary_contact='trent@lloyd.id.au',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='unknown'),
#  'bad_example': Project(name='bad_example',
#                         language='c++',
#                         homepage='http://www.zlib.net/',
#                         main_repo='https://github.com/madler/zlib',
#                         primary_contact=None,
#                         vendor_ccs=[],
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='make'),
#  'bazel-rules-fuzzing-test': Project(name='bazel-rules-fuzzing-test',
#                                      language='c++',
#                                      homepage='https://github.com/bazelbuild/rules_fuzzing',
#                                      main_repo='https://github.com/bazelbuild/rules_fuzzing',
#                                      primary_contact='test@example.com',
#                                      vendor_ccs=None,
#                                      fuzzing_engines=['libfuzzer',
#                                                       'afl',
#                                                       'honggfuzz'],
#                                      build_system='bazel'),
#  'bearssl': Project(name='bearssl',
#                     language='c++',
#                     homepage='https://bearssl.org/',
#                     main_repo='https://www.bearssl.org/git/BearSSL',
#                     primary_contact='guidovranken@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=None,
#                     build_system='make'),
#  'behaviortreecpp': Project(name='behaviortreecpp',
#                             language='c++',
#                             homepage='https://www.behaviortree.dev/',
#                             main_repo='https://github.com/BehaviorTree/BehaviorTree.CPP',
#                             primary_contact='christopher.krah@tii.ae',
#                             vendor_ccs=['dfaconti@aurynrobotics.com'],
#                             fuzzing_engines=['libfuzzer', 'afl'],
#                             build_system='cmake'),
#  'bignum-fuzzer': Project(name='bignum-fuzzer',
#                           language='c++',
#                           homepage='https://github.com/guidovranken/bignum-fuzzer',
#                           main_repo='https://github.com/guidovranken/bignum-fuzzer',
#                           primary_contact='guidovranken@gmail.com',
#                           vendor_ccs=None,
#                           fuzzing_engines=['libfuzzer', 'honggfuzz'],
#                           build_system='cmake'),
#  'binutils': Project(name='binutils',
#                      language='c++',
#                      homepage='https://www.gnu.org/software/binutils/',
#                      main_repo='https://github.com/bminor/binutils-gdb',
#                      primary_contact='bug-binutils@gnu.org',
#                      vendor_ccs=None,
#                      fuzzing_engines=None,
#                      build_system='make'),
#  'bitcoin-core': Project(name='bitcoin-core',
#                          language='c++',
#                          homepage='https://bitcoincore.org/',
#                          main_repo='https://github.com/bitcoin/bitcoin.git',
#                          primary_contact='macro.fuzzing.uxuga@aleeas.com',
#                          vendor_ccs=None,
#                          fuzzing_engines=['afl', 'libfuzzer', 'honggfuzz'],
#                          build_system='cmake'),
#  'bloaty': Project(name='bloaty',
#                    language='c++',
#                    homepage='https://github.com/google/bloaty',
#                    main_repo='https://github.com/google/bloaty.git',
#                    primary_contact='jhaberman@gmail.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=None,
#                    build_system='cmake'),
#  'bls-signatures': Project(name='bls-signatures',
#                            language='c++',
#                            homepage='https://github.com/supranational/blst',
#                            main_repo='https://github.com/supranational/blst.git',
#                            primary_contact='guidovranken@gmail.com',
#                            vendor_ccs=None,
#                            fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                            build_system='cmake'),
#  'boost': Project(name='boost',
#                   language='c++',
#                   homepage='http://www.boost.org/',
#                   main_repo='https://github.com/boostorg/boost.git',
#                   primary_contact='mclow@boost.org',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='unknown'),
#  'boost-beast': Project(name='boost-beast',
#                         language='c++',
#                         homepage='https://www.boost.org/',
#                         main_repo='https://github.com/boostorg/beast.git',
#                         primary_contact='vinnie.falco@gmail.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='unknown'),
#  'boost-json': Project(name='boost-json',
#                        language='c++',
#                        homepage='http://www.boost.org/',
#                        main_repo='https://github.com/boostorg/json.git',
#                        primary_contact='pauldreikossfuzz@gmail.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=None,
#                        build_system='unknown'),
#  'boringssl': Project(name='boringssl',
#                       language='c++',
#                       homepage='https://boringssl.googlesource.com/boringssl/',
#                       main_repo='https://boringssl.googlesource.com/boringssl',
#                       primary_contact='agl@google.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=None,
#                       build_system='cmake'),
#  'botan': Project(name='botan',
#                   language='c++',
#                   homepage='https://botan.randombit.net',
#                   main_repo='https://github.com/randombit/botan.git',
#                   primary_contact='jack.lloyd@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl',
#                                    'centipede',
#                                    'honggfuzz',
#                                    'libfuzzer'],
#                   build_system='make'),
#  'brotli': Project(name='brotli',
#                    language='c++',
#                    homepage='https://github.com/google/brotli',
#                    main_repo='https://github.com/google/brotli.git',
#                    primary_contact='eustas@chromium.org',
#                    vendor_ccs=['jkew@mozilla.com', 'twsmith@mozilla.com'],
#                    fuzzing_engines=None,
#                    build_system='cmake'),
#  'brpc': Project(name='brpc',
#                  language='c++',
#                  homepage='https://brpc.apache.org',
#                  main_repo='https://github.com/apache/incubator-brpc',
#                  primary_contact='security@apache.org',
#                  vendor_ccs=['zhujiashun2010@gmail.com',
#                              'wangweibing@baidu.com',
#                              'serverglen@gmail.com',
#                              'jerrytan@apache.org'],
#                  fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                  build_system=None),
#  'brunsli': Project(name='brunsli',
#                     language='c++',
#                     homepage='https://github.com/google/brunsli',
#                     main_repo='https://github.com/google/brunsli.git',
#                     primary_contact='eustas@chromium.org',
#                     vendor_ccs=['jkew@mozilla.com', 'twsmith@mozilla.com'],
#                     fuzzing_engines=None,
#                     build_system='cmake'),
#  'bzip2': Project(name='bzip2',
#                   language='c++',
#                   homepage='https://sourceware.org/bzip2/',
#                   main_repo=None,
#                   primary_contact='bzip2fuzzer@gmail.com',
#                   vendor_ccs=['twsmith@mozilla.com'],
#                   fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                   build_system='unknown'),
#  'c-ares': Project(name='c-ares',
#                    language='c++',
#                    homepage='https://c-ares.haxx.se/',
#                    main_repo='https://github.com/c-ares/c-ares.git',
#                    primary_contact='drysdale@google.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'libfuzzer', 'honggfuzz'],
#                    build_system='make'),
#  'c-blosc': Project(name='c-blosc',
#                     language='c++',
#                     homepage='https://github.com/Blosc/c-blosc',
#                     main_repo='https://github.com/Blosc/c-blosc.git',
#                     primary_contact='blosc.oss.fuzz@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=None,
#                     build_system='cmake'),
#  'c-blosc2': Project(name='c-blosc2',
#                      language='c++',
#                      homepage='https://github.com/Blosc/c-blosc2',
#                      main_repo='https://github.com/Blosc/c-blosc2.git',
#                      primary_contact='blosc.oss.fuzz@gmail.com',
#                      vendor_ccs=None,
#                      fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                      build_system='cmake'),
#  'capnproto': Project(name='capnproto',
#                       language='c++',
#                       homepage='https://capnproto.org',
#                       main_repo='https://github.com/capnproto/capnproto',
#                       primary_contact='security@sandstorm.io',
#                       vendor_ccs=None,
#                       fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                       build_system='make'),
#  'capstone': Project(name='capstone',
#                      language='c++',
#                      homepage='https://www.capstone-engine.org',
#                      main_repo='https://github.com/capstone-engine/capstone.git',
#                      primary_contact='capstone.engine@gmail.com',
#                      vendor_ccs=None,
#                      fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                      build_system='cmake'),
#  'casync': Project(name='casync',
#                    language='c++',
#                    homepage='https://github.com/casync/casync',
#                    main_repo='https://github.com/systemd/casync',
#                    primary_contact='lennart@poettering.net',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='unknown'),
#  'catapult': Project(name='catapult',
#                      language=None,
#                      homepage='https://github.com/nemtech/catapult-server',
#                      main_repo='https://github.com/nemtech/catapult-server',
#                      primary_contact='wayonb@gmail.com',
#                      vendor_ccs=None,
#                      fuzzing_engines=None,
#                      build_system=None),
#  'cctz': Project(name='cctz',
#                  language='c++',
#                  homepage='https://github.com/google/cctz',
#                  main_repo='https://github.com/google/cctz',
#                  primary_contact=None,
#                  vendor_ccs=['david@adalogics.com'],
#                  fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                  build_system='cmake'),
#  'cel-cpp': Project(name='cel-cpp',
#                     language='c++',
#                     homepage='https://opensource.google/projects/cel',
#                     main_repo='https://github.com/google/cel-cpp',
#                     primary_contact='kyessenov@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='bazel'),
#  'cfengine': Project(name='cfengine',
#                      language='c++',
#                      homepage='https://github.com/cfengine/core',
#                      main_repo='https://github.com/cfengine/core',
#                      primary_contact='vratislav.podzimek@northern.tech',
#                      vendor_ccs=None,
#                      fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                      build_system='make'),
#  'cifuzz-example': Project(name='cifuzz-example',
#                            language='c++',
#                            homepage=None,
#                            main_repo='https://github.com/jonathanmetzman/cifuzz-example.git',
#                            primary_contact='fake@example.com',
#                            vendor_ccs=None,
#                            fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                            build_system='make'),
#  'circl': Project(name='circl',
#                   language='c++',
#                   homepage='https://github.com/cloudflare/circl',
#                   main_repo='https://github.com/cloudflare/circl.git',
#                   primary_contact='guidovranken@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=None,
#                   build_system='make'),
#  'cjson': Project(name='cjson',
#                   language='c++',
#                   homepage='https://github.com/DaveGamble/cJSON',
#                   main_repo='https://github.com/DaveGamble/cJSON.git',
#                   primary_contact='max@maxbruckner.de',
#                   vendor_ccs=None,
#                   fuzzing_engines=None,
#                   build_system='unknown'),
#  'clamav': Project(name='clamav',
#                    language='c++',
#                    homepage='https://www.clamav.net/',
#                    main_repo='https://github.com/Cisco-Talos/clamav-devel.git',
#                    primary_contact='clamav.fuzz@gmail.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=['libfuzzer', 'afl'],
#                    build_system='cmake'),
#  'clickhouse': Project(name='clickhouse',
#                        language='c++',
#                        homepage='https://clickhouse.com/',
#                        main_repo='https://github.com/ClickHouse/ClickHouse.git',
#                        primary_contact='security@clickhouse.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='cmake'),
#  'cmark': Project(name='cmark',
#                   language='c++',
#                   homepage='http://commonmark.org',
#                   main_repo='https://github.com/commonmark/cmark.git',
#                   primary_contact='jgm@berkeley.edu',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                   build_system='cmake'),
#  'connectedhomeip': Project(name='connectedhomeip',
#                             language='c++',
#                             homepage='https://buildwithmatter.com/',
#                             main_repo='https://github.com/project-chip/connectedhomeip.git',
#                             primary_contact='andreilitvin@google.com',
#                             vendor_ccs=None,
#                             fuzzing_engines=['libfuzzer',
#                                              'honggfuzz',
#                                              'centipede'],
#                             build_system='ninja'),
#  'coreutils': Project(name='coreutils',
#                       language=None,
#                       homepage='http://www.gnu.org/software/coreutils/',
#                       main_repo='https://github.com/coreutils/coreutils',
#                       primary_contact='P@draigBrady.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=None,
#                       build_system=None),
#  'cpp-httplib': Project(name='cpp-httplib',
#                         language='c++',
#                         homepage='https://github.com/yhirose/cpp-httplib',
#                         main_repo='https://github.com/yhirose/cpp-httplib.git',
#                         primary_contact='yuji.hirose.bug@gmail.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='make'),
#  'cppcheck': Project(name='cppcheck',
#                      language='c++',
#                      homepage='https://cppcheck.sourceforge.net',
#                      main_repo='https://github.com/danmar/cppcheck.git',
#                      primary_contact='daniel.marjamaki@gmail.com',
#                      vendor_ccs=None,
#                      fuzzing_engines=None,
#                      build_system='make'),
#  'cppitertools': Project(name='cppitertools',
#                          language='c++',
#                          homepage='https://github.com/ryanhaining/cppitertools',
#                          main_repo='https://github.com/ryanhaining/cppitertools',
#                          primary_contact=None,
#                          vendor_ccs=['david@adalogics.com'],
#                          fuzzing_engines=None,
#                          build_system='unknown'),
#  'cpython3': Project(name='cpython3',
#                      language='c++',
#                      homepage='https://python.org/',
#                      main_repo='https://github.com/python/cpython',
#                      primary_contact='seth@python.org',
#                      vendor_ccs=None,
#                      fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                      build_system='make'),
#  'crow': Project(name='crow',
#                  language='c++',
#                  homepage='https://crowcpp.org/master/',
#                  main_repo='https://github.com/CrowCpp/Crow',
#                  primary_contact='capuanobailey@gmail.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=None,
#                  build_system=None),
#  'cryptofuzz': Project(name='cryptofuzz',
#                        language='c++',
#                        homepage='https://github.com/guidovranken/cryptofuzz',
#                        main_repo='https://github.com/guidovranken/cryptofuzz',
#                        primary_contact='guidovranken@gmail.com',
#                        vendor_ccs=['oss-fuzz@mozilla-fuzzing.iam.gserviceaccount.com'],
#                        fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                        build_system='cmake'),
#  'cups-filters': Project(name='cups-filters',
#                          language='c++',
#                          homepage='https://github.com/OpenPrinting/cups-filters',
#                          main_repo='https://github.com/OpenPrinting/cups-filters.git',
#                          primary_contact='jiongchiyu@gmail.com',
#                          vendor_ccs=None,
#                          fuzzing_engines=['libfuzzer'],
#                          build_system=None),
#  'cura-engine': Project(name='cura-engine',
#                         language='c++',
#                         homepage='https://github.com/Ultimaker/CuraEngine',
#                         main_repo='https://github.com/Ultimaker/CuraEngine.git',
#                         primary_contact='j.vankessel@ultimaker.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system=None),
#  'curl': Project(name='curl',
#                  language='c++',
#                  homepage='https://curl.haxx.se/',
#                  main_repo='https://github.com/curl/curl.git',
#                  primary_contact='daniel@haxx.se',
#                  vendor_ccs=None,
#                  fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                  build_system='unknown'),
#  'cxxopts': Project(name='cxxopts',
#                     language='c++',
#                     homepage='https://github.com/jarro2783/cxxopts',
#                     main_repo='https://github.com/jarro2783/cxxopts',
#                     primary_contact='jarro.2783@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='bazel'),
#  'dart': Project(name='dart',
#                  language='c++',
#                  homepage='https://dart.dev',
#                  main_repo='https://github.com/dart-lang/sdk.git',
#                  primary_contact='scheglov@google.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=['libfuzzer'],
#                  build_system='unknown'),
#  'date': Project(name='date',
#                  language='c++',
#                  homepage='https://howardhinnant.github.io/date/date.html',
#                  main_repo='https://github.com/HowardHinnant/date',
#                  primary_contact='capuanobailey@gmail.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=None,
#                  build_system=None),
#  'dav1d': Project(name='dav1d',
#                   language='c++',
#                   homepage='https://code.videolan.org/videolan/dav1d',
#                   main_repo='https://code.videolan.org/videolan/dav1d.git',
#                   primary_contact='janne.grunau@gmail.com',
#                   vendor_ccs=['twsmith@mozilla.com'],
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='ninja'),
#  'dlplibs': Project(name='dlplibs',
#                     language='c++',
#                     homepage='https://www.documentliberation.org',
#                     main_repo=None,
#                     primary_contact='dtardon@redhat.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'dng_sdk': Project(name='dng_sdk',
#                     language='c++',
#                     homepage='https://android.googlesource.com/platform/external/dng_sdk/',
#                     main_repo='https://android.googlesource.com/platform/external/dng_sdk/',
#                     primary_contact='adaubert@google.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='unknown'),
#  'double-conversion': Project(name='double-conversion',
#                               language='c++',
#                               homepage='https://github.com/google/double-conversion',
#                               main_repo='https://github.com/google/double-conversion.git',
#                               primary_contact='florian@loitsch.com',
#                               vendor_ccs=None,
#                               fuzzing_engines=None,
#                               build_system='cmake'),
#  'dpp': Project(name='dpp',
#                 language='c++',
#                 homepage='https://github.com/brainboxdotcc/DPP',
#                 main_repo='https://github.com/brainboxdotcc/DPP.git',
#                 primary_contact='craigedwardsbrainbox@gmail.com',
#                 vendor_ccs=None,
#                 fuzzing_engines=None,
#                 build_system=None),
#  'draco': Project(name='draco',
#                   language='c++',
#                   homepage='https://github.com/google/draco',
#                   main_repo='https://github.com/google/draco',
#                   primary_contact='fgalligan@google.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'honggfuzz', 'centipede'],
#                   build_system='unknown'),
#  'dropbear': Project(name='dropbear',
#                      language='c++',
#                      homepage='https://matt.ucc.asn.au/dropbear/dropbear.html',
#                      main_repo='https://github.com/mkj/dropbear',
#                      primary_contact='matt@ucc.asn.au',
#                      vendor_ccs=None,
#                      fuzzing_engines=None,
#                      build_system='make'),
#  'duckdb': Project(name='duckdb',
#                    language='c++',
#                    homepage='https://duckdb.org/',
#                    main_repo='https://github.com/duckdb/duckdb/',
#                    primary_contact='quack@duckdb.org',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='make'),
#  'easywsclient': Project(name='easywsclient',
#                          language='c++',
#                          homepage='https://github.com/dhbaird/easywsclient',
#                          main_repo='https://github.com/dhbaird/easywsclient',
#                          primary_contact='dhbaird@gmail.com',
#                          vendor_ccs=None,
#                          fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                          build_system='unknown'),
#  'ecc-diff-fuzzer': Project(name='ecc-diff-fuzzer',
#                             language='c++',
#                             homepage='https://github.com/catenacyber/elliptic-curve-differential-fuzzer',
#                             main_repo='https://github.com/catenacyber/elliptic-curve-differential-fuzzer',
#                             primary_contact='p.antoine@catenacyber.fr',
#                             vendor_ccs=None,
#                             fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                             build_system='cmake'),
#  'eigen': Project(name='eigen',
#                   language='c++',
#                   homepage='http://eigen.tuxfamily.org/index.php?title=Main_Page',
#                   main_repo='https://gitlab.com/libeigen/eigen.git',
#                   primary_contact='eigen-core-team@lists.tuxfamily.org',
#                   vendor_ccs=None,
#                   fuzzing_engines=None,
#                   build_system='cmake'),
#  'elfutils': Project(name='elfutils',
#                      language='c++',
#                      homepage='https://sourceware.org/elfutils/',
#                      main_repo='https://sourceware.org/git/elfutils.git',
#                      primary_contact='elfutils-devel@sourceware.org',
#                      vendor_ccs=None,
#                      fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                      build_system='make'),
#  'envoy': Project(name='envoy',
#                   language='c++',
#                   homepage='https://www.envoyproxy.io/',
#                   main_repo='https://github.com/envoyproxy/envoy.git',
#                   primary_contact='htuch@google.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'honggfuzz'],
#                   build_system='make'),
#  'esp-v2': Project(name='esp-v2',
#                    language='c++',
#                    homepage='https://github.com/GoogleCloudPlatform/esp-v2',
#                    main_repo='https://github.com/GoogleCloudPlatform/esp-v2.git',
#                    primary_contact='nareddyt@google.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='make'),
#  'espeak-ng': Project(name='espeak-ng',
#                       language='c++',
#                       homepage='https://github.com/espeak-ng/espeak-ng',
#                       main_repo='https://github.com/espeak-ng/espeak-ng',
#                       primary_contact='msclrhd@googlemail.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=['libfuzzer', 'afl'],
#                       build_system='make'),
#  'example': Project(name='example',
#                     language='c++',
#                     homepage='https://my-api.example.com',
#                     main_repo='https://github.com/example/my-api',
#                     primary_contact=None,
#                     vendor_ccs=[],
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'exiv2': Project(name='exiv2',
#                   language='c++',
#                   homepage='https://www.exiv2.org',
#                   main_repo='https://github.com/Exiv2/exiv2',
#                   primary_contact='kevinbackhouse@github.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='cmake'),
#  'expat': Project(name='expat',
#                   language='c++',
#                   homepage='https://github.com/libexpat/libexpat',
#                   main_repo='https://github.com/libexpat/libexpat',
#                   primary_contact='sebastian@pipping.org',
#                   vendor_ccs=['twsmith@mozilla.com'],
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='cmake'),
#  'exprtk': Project(name='exprtk',
#                    language='c++',
#                    homepage='https://www.partow.net/programming/exprtk/index.html',
#                    main_repo='https://github.com/ArashPartow/exprtk.git',
#                    primary_contact='exprtk.dev@gmail.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                    build_system='unknown'),
#  'fast-dds': Project(name='fast-dds',
#                      language='c++',
#                      homepage='https://www.eprosima.com/',
#                      main_repo='https://github.com/eProsima/Fast-DDS.git',
#                      primary_contact='miguelcompany@eprosima.com',
#                      vendor_ccs=None,
#                      fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                      build_system='cmake'),
#  'fast_float': Project(name='fast_float',
#                        language='c++',
#                        homepage='https://github.com/fastfloat/fast_float',
#                        main_repo='https://github.com/fastfloat/fast_float.git',
#                        primary_contact='lemire@gmail.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                        build_system=None),
#  'ffmpeg': Project(name='ffmpeg',
#                    language='c++',
#                    homepage='https://www.ffmpeg.org',
#                    main_repo='https://git.ffmpeg.org/ffmpeg.git',
#                    primary_contact='ffmpeg-security@ffmpeg.org',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='make'),
#  'ffms2': Project(name='ffms2',
#                   language='c++',
#                   homepage='https://github.com/FFMS/ffms2',
#                   main_repo='https://github.com/FFMS/ffms2',
#                   primary_contact=None,
#                   vendor_ccs=['david@adalogics.com',
#                               'arthur.chan@adalogics.com'],
#                   fuzzing_engines=['libfuzzer', 'honggfuzz'],
#                   build_system='make'),
#  'fftw3': Project(name='fftw3',
#                   language='c++',
#                   homepage='http://fftw.org/',
#                   main_repo='https://github.com/fftw/fftw3.git',
#                   primary_contact=None,
#                   vendor_ccs=['david@adlogics.com',
#                               'arthur.chan@adalogics.com'],
#                   fuzzing_engines=None,
#                   build_system='make'),
#  'file': Project(name='file',
#                  language='c++',
#                  homepage='http://www.darwinsys.com/file/',
#                  main_repo='https://github.com/file/file.git',
#                  primary_contact='zoulasc@gmail.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=None,
#                  build_system='make'),
#  'fio': Project(name='fio',
#                 language='c++',
#                 homepage='http://git.kernel.dk/fio.git',
#                 main_repo='https://github.com/axboe/fio.git',
#                 primary_contact='axboe@kernel.dk',
#                 vendor_ccs=None,
#                 fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                 build_system='make'),
#  'firefox': Project(name='firefox',
#                     language='c++',
#                     homepage='https://www.mozilla.org/firefox/',
#                     main_repo='https://hg.mozilla.org/mozilla-central/',
#                     primary_contact='choller@mozilla.com',
#                     vendor_ccs=['oss-fuzz@mozilla-fuzzing.iam.gserviceaccount.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'firestore': Project(name='firestore',
#                       language='c++',
#                       homepage='https://firebase.google.com/docs/firestore/',
#                       main_repo='https://github.com/firebase/firebase-ios-sdk.git',
#                       primary_contact='varconst@google.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=None,
#                       build_system='cmake'),
#  'flac': Project(name='flac',
#                  language='c++',
#                  homepage='https://xiph.org/flac/',
#                  main_repo='https://github.com/xiph/flac.git',
#                  primary_contact='mvanb1@gmail.com',
#                  vendor_ccs=['twsmith@mozilla.com'],
#                  fuzzing_engines=None,
#                  build_system='make'),
#  'flatbuffers': Project(name='flatbuffers',
#                         language='c++',
#                         homepage='https://github.com/google/flatbuffers',
#                         main_repo='https://github.com/google/flatbuffers',
#                         primary_contact='derekbailey@google.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='cmake'),
#  'fluent-bit': Project(name='fluent-bit',
#                        language='c++',
#                        homepage='https://github.com/fluent/fluent-bit',
#                        main_repo='https://github.com/fluent/fluent-bit/',
#                        primary_contact='edsiper@gmail.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                        build_system='cmake'),
#  'fmt': Project(name='fmt',
#                 language='c++',
#                 homepage='https://github.com/fmtlib/fmt',
#                 main_repo='https://github.com/fmtlib/fmt.git',
#                 primary_contact='pauldreikossfuzz@gmail.com',
#                 vendor_ccs=None,
#                 fuzzing_engines=None,
#                 build_system='cmake'),
#  'freeimage': Project(name='freeimage',
#                       language='c++',
#                       homepage='http://freeimage.sourceforge.net/',
#                       main_repo='https://svn.code.sf.net/p/freeimage/svn/',
#                       primary_contact='drolon@infonie.fr',
#                       vendor_ccs=None,
#                       fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                       build_system='make'),
#  'freeradius': Project(name='freeradius',
#                        language='c++',
#                        homepage='https://freeradius.org',
#                        main_repo='https://github.com/FreeRADIUS/freeradius-server.git',
#                        primary_contact='a.cudbardb@gmail.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=['libfuzzer'],
#                        build_system='make'),
#  'freetype2': Project(name='freetype2',
#                       language='c++',
#                       homepage='https://www.freetype.org/',
#                       main_repo='https://github.com/freetype/freetype2-testing.git',
#                       primary_contact='lemzwerg@gmail.com',
#                       vendor_ccs=['jkew@mozilla.com',
#                                   'jmuizelaar@mozilla.com',
#                                   'lsalzman@mozilla.com',
#                                   'twsmith@mozilla.com'],
#                       fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                       build_system='cmake'),
#  'frr': Project(name='frr',
#                 language='c++',
#                 homepage='https://frrouting.org',
#                 main_repo='https://github.com/FRRouting/frr',
#                 primary_contact='security@lists.frrouting.org',
#                 vendor_ccs=None,
#                 fuzzing_engines=['libfuzzer'],
#                 build_system='cmake'),
#  'fuzzing-puzzles': Project(name='fuzzing-puzzles',
#                             language='c++',
#                             homepage='https://github.com/google/fuzzer-test-suite',
#                             main_repo='https://github.com/google/fuzzer-test-suite',
#                             primary_contact='kcc@google.com',
#                             vendor_ccs=None,
#                             fuzzing_engines=['honggfuzz'],
#                             build_system='unknown'),
#  'fuzztest-example': Project(name='fuzztest-example',
#                              language='c++',
#                              homepage='https://github.com/google/fuzztest',
#                              main_repo='https://github.com/google/fuzztest',
#                              primary_contact='david@adalogics.com',
#                              vendor_ccs=None,
#                              fuzzing_engines=['libfuzzer'],
#                              build_system='unknown'),
#  'fuzztest-raksha': Project(name='fuzztest-raksha',
#                             language='c++',
#                             homepage='https://github.com/google/fuzztest',
#                             main_repo='https://github.com/google/fuzztest',
#                             primary_contact='david@adalogics.com',
#                             vendor_ccs=None,
#                             fuzzing_engines=['libfuzzer'],
#                             build_system='unknown'),
#  'gdal': Project(name='gdal',
#                  language='c++',
#                  homepage='https://gdal.org',
#                  main_repo='https://github.com/OSGeo/gdal',
#                  primary_contact='even.rouault@gmail.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                  build_system=None),
#  'geos': Project(name='geos',
#                  language='c++',
#                  homepage='https://geos.osgeo.org',
#                  main_repo='https://git.osgeo.org/gitea/geos/geos.git',
#                  primary_contact='mtnclimb@gmail.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                  build_system='cmake'),
#  'gfwx': Project(name='gfwx',
#                  language='c++',
#                  homepage='http://www.gfwx.org/',
#                  main_repo='https://github.com/kalcutter/gfwx',
#                  primary_contact='fyffe@google.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                  build_system='make'),
#  'ghostscript': Project(name='ghostscript',
#                         language='c++',
#                         homepage='https://ghostscript.com',
#                         main_repo='git://git.ghostscript.com/ghostpdl.git',
#                         primary_contact='skau@google.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['libfuzzer', 'honggfuzz'],
#                         build_system='make'),
#  'giflib': Project(name='giflib',
#                    language='c++',
#                    homepage='http://giflib.sourceforge.net/',
#                    main_repo='https://git.code.sf.net/p/giflib/code',
#                    primary_contact='esr@thyrsus.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='unknown'),
#  'git': Project(name='git',
#                 language='c++',
#                 homepage='https://git-scm.com',
#                 main_repo='https://github.com/git/git',
#                 primary_contact='steadmon@google.com',
#                 vendor_ccs=None,
#                 fuzzing_engines=['libfuzzer', 'afl'],
#                 build_system='make'),
#  'glaze': Project(name='glaze',
#                   language='c++',
#                   homepage='https://github.com/stephenberry/glaze',
#                   main_repo='https://github.com/stephenberry/glaze.git',
#                   primary_contact='pauldreikossfuzz@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=None,
#                   build_system='unknown'),
#  'glib': Project(name='glib',
#                  language='c++',
#                  homepage='https://gitlab.gnome.org/GNOME/glib/',
#                  main_repo='https://gitlab.gnome.org/GNOME/glib',
#                  primary_contact='bugzilla@tecnocode.co.uk',
#                  vendor_ccs=None,
#                  fuzzing_engines=None,
#                  build_system='ninja'),
#  'glog': Project(name='glog',
#                  language='c++',
#                  homepage='https://github.com/google/glog',
#                  main_repo='https://github.com/google/glog',
#                  primary_contact='sergiu.deitsch@gmail.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                  build_system='cmake'),
#  'glslang': Project(name='glslang',
#                     language='c++',
#                     homepage='https://github.com/khronosgroup/glslang',
#                     main_repo='https://github.com/khronosgroup/glslang',
#                     primary_contact=None,
#                     vendor_ccs=['david@adalogics.com',
#                                 'arthur.chan@adalogics.com'],
#                     fuzzing_engines=None,
#                     build_system='cmake'),
#  'gnupg': Project(name='gnupg',
#                   language='c++',
#                   homepage='https://www.gnupg.org',
#                   main_repo='git://git.gnupg.org/gnupg.git',
#                   primary_contact='p.antoine@catenacyber.fr',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'honggfuzz'],
# ...
#  'opennavsurf-bag': Project(name='opennavsurf-bag',
#                             language='c++',
#                             homepage='https://github.com/OpenNavigationSurface/BAG',
#                             main_repo='https://github.com/OpenNavigationSurface/BAG',
#                             primary_contact='selimnairb@gmail.com',
#                             vendor_ccs=None,
#                             fuzzing_engines=None,
#                             build_system=None),
#  'opensc': Project(name='opensc',
#                    language='c++',
#                    homepage='https://github.com/OpenSC/OpenSC/',
#                    main_repo='https://github.com/OpenSC/OpenSC',
#                    primary_contact='frankmorgner@gmail.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                    build_system='make'),
#  'openssh': Project(name='openssh',
#                     language='c++',
#                     homepage='https://www.openssh.com/',
#                     main_repo='https://github.com/openssh/openssh-portable',
#                     primary_contact='djm@mindrot.org',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'openssl': Project(name='openssl',
#                     language='c++',
#                     homepage='https://www.openssl.org/',
#                     main_repo='https://github.com/openssl/openssl.git',
#                     primary_contact='kurt@roeckx.be',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'openthread': Project(name='openthread',
#                        language='c++',
#                        homepage='https://github.com/openthread/openthread',
#                        main_repo='https://github.com/openthread/openthread',
#                        primary_contact='jonhui@google.com',
#                        vendor_ccs=None,
#                        fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                        build_system='unknown'),
#  'openvswitch': Project(name='openvswitch',
#                         language='c++',
#                         homepage='http://www.openvswitch.org',
#                         main_repo='https://github.com/openvswitch/ovs.git',
#                         primary_contact='blp@ovn.org',
#                         vendor_ccs=None,
#                         fuzzing_engines=None,
#                         build_system='make'),
#  'openweave': Project(name='openweave',
#                       language='c++',
#                       homepage='https://openweave.io',
#                       main_repo='https://github.com/openweave/openweave-core',
#                       primary_contact='szewczyk@google.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='make'),
#  'opus': Project(name='opus',
#                  language='c++',
#                  homepage='https://opus-codec.org/',
#                  main_repo='https://gitlab.xiph.org/xiph/opus.git',
#                  primary_contact='jmvalin@jmvalin.ca',
#                  vendor_ccs=['twsmith@mozilla.com'],
#                  fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                  build_system='make'),
#  'osquery': Project(name='osquery',
#                     language='c++',
#                     homepage='https://osquery.io',
#                     main_repo='https://github.com/osquery/osquery',
#                     primary_contact='osquery@osquery.io',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer', 'afl'],
#                     build_system='cmake'),
#  'ots': Project(name='ots',
#                 language='c++',
#                 homepage='https://github.com/khaledhosny/ots',
#                 main_repo='https://github.com/khaledhosny/ots.git',
#                 primary_contact='dr.khaled.hosny@gmail.com',
#                 vendor_ccs=['jmuizelaar@mozilla.com',
#                             'lsalzman@mozilla.com',
#                             'twsmith@mozilla.com'],
#                 fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                 build_system='ninja'),
#  'pcapplusplus': Project(name='pcapplusplus',
#                          language='c++',
#                          homepage='https://github.com/seladb/PcapPlusPlus',
#                          main_repo='https://github.com/seladb/PcapPlusPlus',
#                          primary_contact='pcapplusplus@gmail.com',
#                          vendor_ccs=None,
#                          fuzzing_engines=['afl', 'libfuzzer'],
#                          build_system='unknown'),
#  'pcl': Project(name='pcl',
#                 language='c++',
#                 homepage='http://pointclouds.org',
#                 main_repo='https://github.com/pointcloudlibrary/pcl',
#                 primary_contact='kunal.tyagi.3.1994@gmail.com',
#                 vendor_ccs=None,
#                 fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                 build_system='unknown'),
#  'pcre2': Project(name='pcre2',
#                   language='c++',
#                   homepage='http://www.pcre.org/',
#                   main_repo='https://github.com/PCRE2Project/pcre2',
#                   primary_contact='nicholas@nickcwilson.co.uk',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'afl'],
#                   build_system='make'),
#  'perfetto': Project(name='perfetto',
#                      language='c++',
#                      homepage='https://perfetto.dev',
#                      main_repo='https://android.googlesource.com/platform/external/perfetto/',
#                      primary_contact='hjd@google.com',
#                      vendor_ccs=['adambacchus@google.com',
#                                  'ailport@google.com',
#                                  'bcreasey@google.com',
#                                  'cunefare@google.com',
#                                  'ejorgensen@google.com',
#                                  'faerber@google.com',
#                                  'greendonald@google.com',
#                                  'hamzeh@google.com',
#                                  'jaredkidd@google.com',
#                                  'kimtony@google.com',
#                                  'lindsaywells@google.com',
#                                  'maverickm@google.com',
#                                  'swansonr@google.com',
#                                  'warrenwright@google.com'],
#                      fuzzing_engines=None,
#                      build_system='unknown'),
#  'pffft': Project(name='pffft',
#                   language='c++',
#                   homepage='https://bitbucket.org/jpommier/pffft',
#                   main_repo='https://bitbucket.org/jpommier/pffft.git',
#                   primary_contact='pommier@modartt.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                   build_system='unknown'),
#  'phmap': Project(name='phmap',
#                   language='c++',
#                   homepage='https://github.com/greg7mdp/parallel-hashmap',
#                   main_repo='https://github.com/greg7mdp/parallel-hashmap',
#                   primary_contact='greg7mdp@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='unknown'),
#  'php': Project(name='php',
#                 language='c++',
#                 homepage='http://php.net/',
#                 main_repo='https://github.com/php/php-src.git',
#                 primary_contact='stas@php.net',
#                 vendor_ccs=None,
#                 fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                 build_system='make'),
#  'picotls': Project(name='picotls',
#                     language='c++',
#                     homepage='https://github.com/h2o/picotls',
#                     main_repo='https://github.com/h2o/picotls',
#                     primary_contact='jonathan.foote@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='cmake'),
#  'piex': Project(name='piex',
#                  language='c++',
#                  homepage='https://github.com/google/piex',
#                  main_repo='https://github.com/guidovranken/piex.git',
#                  primary_contact='nchusid@google.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=None,
#                  build_system='make'),
#  'pigweed': Project(name='pigweed',
#                     language='c++',
#                     homepage='https://pigweed.dev/',
#                     main_repo='https://pigweed.googlesource.com/pigweed/pigweed',
#                     primary_contact='keir@google.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl',
#                                      'centipede',
#                                      'honggfuzz',
#                                      'libfuzzer'],
#                     build_system='bazel'),
#  'pistache': Project(name='pistache',
#                      language='c++',
#                      homepage='http://pistache.io',
#                      main_repo='https://github.com/pistacheio/pistache',
#                      primary_contact='kip@thevertigo.com',
#                      vendor_ccs=None,
#                      fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                      build_system='cmake'),
#  'poco': Project(name='poco',
#                  language='c++',
#                  homepage='https://github.com/pocoproject/poco',
#                  main_repo='https://github.com/pocoproject/poco',
#                  primary_contact='guenter@pocoproject.org',
#                  vendor_ccs=None,
#                  fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                  build_system=None),
#  'poppler': Project(name='poppler',
#                     language='c++',
#                     homepage='https://poppler.freedesktop.org/',
#                     main_repo='https://anongit.freedesktop.org/git/poppler/poppler.git',
#                     primary_contact='tsdgeos@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='cmake'),
#  'postgis': Project(name='postgis',
#                     language='c++',
#                     homepage='http://postgis.net/',
#                     main_repo='https://git.osgeo.org/gitea/postgis/postgis.git',
#                     primary_contact='lr@pcorp.us',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'powerdns': Project(name='powerdns',
#                      language='c++',
#                      homepage='https://www.powerdns.com/',
#                      main_repo='https://github.com/PowerDNS/pdns.git',
#                      primary_contact='remi.gacogne@powerdns.com',
#                      vendor_ccs=None,
#                      fuzzing_engines=None,
#                      build_system='make'),
#  'proj4': Project(name='proj4',
#                   language='c++',
#                   homepage='https://proj.org/',
#                   main_repo='https://github.com/OSGeo/PROJ',
#                   primary_contact='even.rouault@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system=None),
#  'proxygen': Project(name='proxygen',
#                      language='c++',
#                      homepage='https://github.com/facebook/proxygen',
#                      main_repo='https://github.com/facebook/proxygen.git',
#                      primary_contact='axxu@fb.com',
#                      vendor_ccs=['oss-fuzz@fb.com'],
#                      fuzzing_engines=['libfuzzer', 'afl'],
#                      build_system='cmake'),
#  'pugixml': Project(name='pugixml',
#                     language='c++',
#                     homepage='https://github.com/zeux/pugixml',
#                     main_repo='https://github.com/zeux/pugixml',
#                     primary_contact='arseny.kapoulkine@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='unknown'),
#  'pybind11': Project(name='pybind11',
#                      language='c++',
#                      homepage='https://pybind11.readthedocs.io/en/stable/',
#                      main_repo='https://github.com/pybind/pybind11.git',
#                      primary_contact=None,
#                      vendor_ccs=['david@adalogics.com',
#                                  'arthur.chan@adalogics.com'],
#                      fuzzing_engines=None,
#                      build_system='cmake'),
#  'qpdf': Project(name='qpdf',
#                  language='c++',
#                  homepage='http://qpdf.sourceforge.net/',
#                  main_repo='https://github.com/qpdf/qpdf.git',
#                  primary_contact='qberkenbilt@gmail.com',
#                  vendor_ccs=None,
#                  fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                  build_system='cmake'),
#  'qpid-proton': Project(name='qpid-proton',
#                         language='c++',
#                         homepage='https://qpid.apache.org/proton/',
#                         main_repo='https://github.com/apache/qpid-proton.git',
#                         primary_contact='jross@apache.org',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='cmake'),
#  'qs': Project(name='qs',
#                language='c++',
#                homepage='https://github.com/ljharb/qs',
#                main_repo='https://github.com/ljharb/qs.git',
#                primary_contact='ljharb@gmail.com',
#                vendor_ccs=None,
#                fuzzing_engines=None,
#                build_system=None),
#  'qt': Project(name='qt',
#                language='c++',
#                homepage='http://qt-project.org',
#                main_repo='git://code.qt.io/qt/qt5.git',
#                primary_contact='rlohningqt@gmail.com',
#                vendor_ccs=None,
#                fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                build_system=None),
#  'quantlib': Project(name='quantlib',
#                      language='c++',
#                      homepage='https://www.quantlib.org/',
#                      main_repo='https://github.com/lballabio/QuantLib.git',
#                      primary_contact='luigi.ballabio@gmail.com',
#                      vendor_ccs=None,
#                      fuzzing_engines=['libfuzzer', 'honggfuzz'],
#                      build_system='cmake'),
#  'qubes-os': Project(name='qubes-os',
#                      language='c++',
#                      homepage='https://www.qubes-os.org/',
#                      main_repo='https://github.com/QubesOS',
#                      primary_contact='jpo@vt.edu',
#                      vendor_ccs=None,
#                      fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                      build_system='make'),
#  'quiche': Project(name='quiche',
#                    language='c++',
#                    homepage='https://github.com/google/quiche',
#                    main_repo='https://github.com/google/quiche',
#                    primary_contact=None,
#                    vendor_ccs=['david@adalogics.com'],
#                    fuzzing_engines=['libfuzzer'],
#                    build_system='bazel'),
#  'racket': Project(name='racket',
#                    language=None,
#                    homepage='https://racket-lang.org',
#                    main_repo='https://github.com/racket/racket/',
#                    primary_contact='pocmatos@gmail.com',
#                    vendor_ccs=None,
#                    fuzzing_engines=None,
#                    build_system=None)}

# %%
# Currently, the function allows partial matching
pp(ossfuzz.match_projects(
    name="ada",    # Matches 'ada-url', 'adal', etc.
))
# Out:
# {'ada-url': Project(name='ada-url',
#                     language='c++',
#                     homepage='https://ada-url.github.io/ada',
#                     main_repo='https://github.com/ada-url/ada.git',
#                     primary_contact='yagiz@nizipli.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer',
#                                      'afl',
#                                      'honggfuzz',
#                                      'centipede'],
#                     build_system=None),
#  'adal': Project(name='adal',
#                  language='python',
#                  homepage='https://github.com/AzureAD/azure-activedirectory-library-for-python',
#                  main_repo='https://github.com/AzureAD/azure-activedirectory-library-for-python',
#                  primary_contact=None,
#                  vendor_ccs=['david@adalogics.com',
#                              'adam@adalogics.com',
#                              'arthur.chan@adalogics.com'],
#                  fuzzing_engines=['libfuzzer'],
#                  build_system='unknown'),
#  'importlib_metadata': Project(name='importlib_metadata',
#                                language='python',
#                                homepage='https://github.com/python/importlib_metadata',
#                                main_repo='https://github.com/python/importlib_metadata',
#                                primary_contact=None,
#                                vendor_ccs=['david@adalogics.com'],
#                                fuzzing_engines=['libfuzzer'],
#                                build_system='unknown'),
#  'metadata-extractor': Project(name='metadata-extractor',
#                                language='jvm',
#                                homepage='https://github.com/drewnoakes/metadata-extractor',
#                                main_repo='https://github.com/drewnoakes/metadata-extractor.git',
#                                primary_contact='',
#                                vendor_ccs=['glendowne@code-intelligence.com',
#                                            'wagner@code-intelligence.com',
#                                            'patrice.salathe@code-intelligence.com',
#                                            'yakdan@code-intelligence.com',
#                                            'hlin@code-intelligence.com',
#                                            'jacek.trossen@code-intelligence.com',
#                                            'bug-disclosure@code-intelligence.com'],
#                                fuzzing_engines=['libfuzzer'],
#                                build_system='unknown')}

# %%
# Currently, the function requires all criteria to match (implicit AND)
pp(ossfuzz.match_projects(
    name="ada",                     # Matches 'ada-url', 'adal', etc.
    fuzzing_engines="honggfuzz",    # Of the 'ada...' projects, only matches 'ada-url'
))
# Out:
# {'ada-url': Project(name='ada-url',
#                     language='c++',
#                     homepage='https://ada-url.github.io/ada',
#                     main_repo='https://github.com/ada-url/ada.git',
#                     primary_contact='yagiz@nizipli.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer',
#                                      'afl',
#                                      'honggfuzz',
#                                      'centipede'],
#                     build_system=None)}

# %% [markdown]
# **Design Decision: More Sophisticated Filtering**
#
# In addition to keyword matching, I implemented a more flexible function for filtering (accidental alliteration). The function takes a predicate as input and returns any project that satisfies the predicate. For instance, the predicate could be a function that checks if a project is:
#
# > (not-in-python OR build-system-missing) AND name-has-odd-characters
#
# This filtering function actually powers the earlier keyword-matching function. The keyword-matching function simply helps users build predicates and passes them along to the filtering function. A disadvantage of this more powerful function is that it requires users to write their own predicates, typically as `lambdas`, which might be difficult for some users. So I think it's good to offer both types of filtering.

# %%
pp(ossfuzz.filter_projects(
    lambda p: (p.language!="python" or p.build_system is None) and (len(p.name) % 2 == 1)),  # We can be as specific as we want
)
# Out:
# {'ada-url': Project(name='ada-url',
#                     language='c++',
#                     homepage='https://ada-url.github.io/ada',
#                     main_repo='https://github.com/ada-url/ada.git',
#                     primary_contact='yagiz@nizipli.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer',
#                                      'afl',
#                                      'honggfuzz',
#                                      'centipede'],
#                     build_system=None),
#  'alembic': Project(name='alembic',
#                     language='c++',
#                     homepage='https://github.com/alembic/alembic',
#                     main_repo='https://github.com/alembic/alembic',
#                     primary_contact='miller.lucas@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=None,
#                     build_system='cmake'),
#  'angular': Project(name='angular',
#                     language='javascript',
#                     homepage='https://angular.io/',
#                     main_repo='https://github.com/angular/angular.git',
#                     primary_contact=None,
#                     vendor_ccs=['wagner@code-intelligence.com',
#                                 'yakdan@code-intelligence.com',
#                                 'patrice.salathe@code-intelligence.com',
#                                 'hlin@code-intelligence.com',
#                                 'christopher.krah@code-intelligence.com',
#                                 'bug-disclosure@code-intelligence.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='bazel'),
#  'antlr3-java': Project(name='antlr3-java',
#                         language='jvm',
#                         homepage='https://www.antlr.org',
#                         main_repo='https://github.com/antlr/antlr3.git',
#                         primary_contact=None,
#                         vendor_ccs=['david@adalogics.com',
#                                     'arthur.chan@adalogics.com'],
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'antlr4-java': Project(name='antlr4-java',
#                         language='jvm',
#                         homepage='https://www.antlr.org',
#                         main_repo='https://github.com/antlr/antlr4.git',
#                         primary_contact='terrence.parr@gmail.com',
#                         vendor_ccs=['wagner@code-intelligence.com',
#                                     'yakdan@code-intelligence.com',
#                                     'glendowne@code-intelligence.com',
#                                     'patrice.salathe@code-intelligence.com',
#                                     'hlin@code-intelligence.com',
#                                     'bug-disclosure@code-intelligence.com'],
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'apache-commons-bcel': Project(name='apache-commons-bcel',
#                                 language='jvm',
#                                 homepage='https://commons.apache.org/proper/commons-bcel/',
#                                 main_repo='https://github.com/apache/commons-bcel.git',
#                                 primary_contact='fuzz-testing@commons.apache.org',
#                                 vendor_ccs=['wagner@code-intelligence.com',
#                                             'yakdan@code-intelligence.com',
#                                             'glendowne@code-intelligence.com',
#                                             'patrice.salathe@code-intelligence.com',
#                                             'hlin@code-intelligence.com',
#                                             'schaich@code-intelligence.com',
#                                             'jacek.trossen@code-intelligence.com',
#                                             'bug-disclosure@code-intelligence.com'],
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='unknown'),
#  'apache-commons-compress': Project(name='apache-commons-compress',
#                                     language='jvm',
#                                     homepage='https://commons.apache.org',
#                                     main_repo='https://github.com/apache/commons-compress',
#                                     primary_contact='fuzz-testing@commons.apache.org',
#                                     vendor_ccs=['wagner@code-intelligence.com',
#                                                 'yakdan@code-intelligence.com',
#                                                 'glendowne@code-intelligence.com',
#                                                 'patrice.salathe@code-intelligence.com',
#                                                 'hlin@code-intelligence.com',
#                                                 'jacek.trossen@code-intelligence.com',
#                                                 'schaich@code-intelligence.com',
#                                                 'norbert.schneider@code-intelligence.com',
#                                                 'bug-disclosure@code-intelligence.com'],
#                                     fuzzing_engines=['libfuzzer'],
#                                     build_system='unknown'),
#  'apache-commons-fileupload': Project(name='apache-commons-fileupload',
#                                       language='jvm',
#                                       homepage='https://commons.apache.org/proper/commons-fileupload/',
#                                       main_repo='https://github.com/apache/commons-fileupload.git',
#                                       primary_contact='fuzz-testing@commons.apache.org',
#                                       vendor_ccs=['wagner@code-intelligence.com',
#                                                   'yakdan@code-intelligence.com',
#                                                   'glendowne@code-intelligence.com',
#                                                   'patrice.salathe@code-intelligence.com',
#                                                   'hlin@code-intelligence.com',
#                                                   'schaich@code-intelligence.com',
#                                                   'jacek.trossen@code-intelligence.com',
#                                                   'bug-disclosure@code-intelligence.com'],
#                                       fuzzing_engines=['libfuzzer'],
#                                       build_system='unknown'),
#  'apache-commons-geometry': Project(name='apache-commons-geometry',
#                                     language='jvm',
#                                     homepage='https://commons.apache.org',
#                                     main_repo='https://github.com/apache/commons-geometry',
#                                     primary_contact='fuzz-testing@commons.apache.org',
#                                     vendor_ccs=['wagner@code-intelligence.com',
#                                                 'yakdan@code-intelligence.com',
#                                                 'glendowne@code-intelligence.com',
#                                                 'patrice.salathe@code-intelligence.com',
#                                                 'hlin@code-intelligence.com',
#                                                 'jacek.trossen@code-intelligence.com',
#                                                 'schaich@code-intelligence.com',
#                                                 'norbert.schneider@code-intelligence.com',
#                                                 'bug-disclosure@code-intelligence.com'],
#                                     fuzzing_engines=['libfuzzer'],
#                                     build_system='unknown'),
#  'apache-commons-io': Project(name='apache-commons-io',
#                               language='jvm',
#                               homepage='https://commons.apache.org/proper/commons-io/',
#                               main_repo='https://gitbox.apache.org/repos/asf/commons-io.git',
#                               primary_contact='fuzz-testing@commons.apache.org',
#                               vendor_ccs=['wagner@code-intelligence.com',
#                                           'yakdan@code-intelligence.com',
#                                           'glendowne@code-intelligence.com',
#                                           'patrice.salathe@code-intelligence.com',
#                                           'hlin@code-intelligence.com',
#                                           'schaich@code-intelligence.com',
#                                           'jacek.trossen@code-intelligence.com',
#                                           'bug-disclosure@code-intelligence.com',
#                                           'david@adalogics.com',
#                                           'adam@adalogics.com',
#                                           'arthur.chan@adalogics.com'],
#                               fuzzing_engines=['libfuzzer'],
#                               build_system='unknown'),
#  'apache-commons-jxpath': Project(name='apache-commons-jxpath',
#                                   language='jvm',
#                                   homepage='https://github.com/apache/commons-jxpath.git',
#                                   main_repo='https://github.com/apache/commons-jxpath.git',
#                                   primary_contact='fuzz-testing@commons.apache.org',
#                                   vendor_ccs=['wagner@code-intelligence.com',
#                                               'yakdan@code-intelligence.com',
#                                               'glendowne@code-intelligence.com',
#                                               'patrice.salathe@code-intelligence.com',
#                                               'hlin@code-intelligence.com',
#                                               'schaich@code-intelligence.com',
#                                               'jacek.trossen@code-intelligence.com',
#                                               'bug-disclosure@code-intelligence.com'],
#                                   fuzzing_engines=['libfuzzer'],
#                                   build_system='unknown'),
#  'apache-commons-lang': Project(name='apache-commons-lang',
#                                 language='jvm',
#                                 homepage='https://github.com/apache/commons-lang',
#                                 main_repo='https://github.com/apache/commons-lang.git',
#                                 primary_contact='fuzz-testing@commons.apache.org',
#                                 vendor_ccs=['wagner@code-intelligence.com',
#                                             'yakdan@code-intelligence.com',
#                                             'glendowne@code-intelligence.com',
#                                             'patrice.salathe@code-intelligence.com',
#                                             'hlin@code-intelligence.com',
#                                             'schaich@code-intelligence.com',
#                                             'jacek.trossen@code-intelligence.com',
#                                             'bug-disclosure@code-intelligence.com',
#                                             'david@adalogics.com',
#                                             'adam@adalogics.com',
#                                             'arthur.chan@adalogics.com'],
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='unknown'),
#  'apache-commons-math': Project(name='apache-commons-math',
#                                 language='jvm',
#                                 homepage='https://commons.apache.org',
#                                 main_repo='https://github.com/apache/commons-math',
#                                 primary_contact='fuzz-testing@commons.apache.org',
#                                 vendor_ccs=['wagner@code-intelligence.com',
#                                             'yakdan@code-intelligence.com',
#                                             'glendowne@code-intelligence.com',
#                                             'patrice.salathe@code-intelligence.com',
#                                             'hlin@code-intelligence.com',
#                                             'jacek.trossen@code-intelligence.com',
#                                             'schaich@code-intelligence.com',
#                                             'norbert.schneider@code-intelligence.com',
#                                             'bug-disclosure@code-intelligence.com'],
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='unknown'),
#  'apache-commons-text': Project(name='apache-commons-text',
#                                 language='jvm',
#                                 homepage='https://github.com/apache/commons-text/',
#                                 main_repo='https://github.com/apache/commons-text/',
#                                 primary_contact='fuzz-testing@commons.apache.org',
#                                 vendor_ccs=['michael.nothhard@code-intelligence.com',
#                                             'glendowne@code-intelligence.com',
#                                             'wagner@code-intelligence.com',
#                                             'patrice.salathe@code-intelligence.com',
#                                             'yakdan@code-intelligence.com',
#                                             'hlin@code-intelligence.com',
#                                             'jacek.trossen@code-intelligence.com',
#                                             'bug-disclosure@code-intelligence.com'],
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='unknown'),
#  'archaius-core': Project(name='archaius-core',
#                           language='jvm',
#                           homepage='https://github.com/Netflix/archaius',
#                           main_repo='https://github.com/Netflix/archaius.git',
#                           primary_contact=None,
#                           vendor_ccs=['wagner@code-intelligence.com',
#                                       'yakdan@code-intelligence.com',
#                                       'glendowne@code-intelligence.com',
#                                       'patrice.salathe@code-intelligence.com',
#                                       'hlin@code-intelligence.com',
#                                       'bug-disclosure@code-intelligence.com'],
#                           fuzzing_engines=['libfuzzer'],
#                           build_system='unknown'),
#  'arduinojson': Project(name='arduinojson',
#                         language='c++',
#                         homepage='https://github.com/bblanchon/ArduinoJson',
#                         main_repo='https://github.com/bblanchon/ArduinoJson.git',
#                         primary_contact='benoit.blanchon@gmail.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=None,
#                         build_system='make'),
#  'arrow': Project(name='arrow',
#                   language='c++',
#                   homepage='https://arrow.apache.org/',
#                   main_repo='https://github.com/apache/arrow.git',
#                   primary_contact='antoine@python.org',
#                   vendor_ccs=None,
#                   fuzzing_engines=None,
#                   build_system='cmake'),
#  'aspectj': Project(name='aspectj',
#                     language='jvm',
#                     homepage='https://www.eclipse.org/aspectj/',
#                     main_repo='https://github.com/eclipse/org.aspectj',
#                     primary_contact=None,
#                     vendor_ccs=['wagner@code-intelligence.com',
#                                 'yakdan@code-intelligence.com',
#                                 'glendowne@code-intelligence.com',
#                                 'patrice.salathe@code-intelligence.com',
#                                 'hlin@code-intelligence.com',
#                                 'schaich@code-intelligence.com',
#                                 'bug-disclosure@code-intelligence.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'async-http-client': Project(name='async-http-client',
#                               language='jvm',
#                               homepage='https://github.com/AsyncHttpClient/async-http-client/',
#                               main_repo='https://github.com/AsyncHttpClient/async-http-client/',
#                               primary_contact='aayush@shieldblaze.com',
#                               vendor_ccs=['wagner@code-intelligence.com',
#                                           'yakdan@code-intelligence.com',
#                                           'glendowne@code-intelligence.com',
#                                           'patrice.salathe@code-intelligence.com',
#                                           'hlin@code-intelligence.com',
#                                           'bug-disclosure@code-intelligence.com'],
#                               fuzzing_engines=['libfuzzer'],
#                               build_system='unknown'),
#  'avahi': Project(name='avahi',
#                   language='c++',
#                   homepage='https://avahi.org/',
#                   main_repo='https://github.com/avahi/avahi',
#                   primary_contact='trent@lloyd.id.au',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='unknown'),
#  'bad_example': Project(name='bad_example',
#                         language='c++',
#                         homepage='http://www.zlib.net/',
#                         main_repo='https://github.com/madler/zlib',
#                         primary_contact=None,
#                         vendor_ccs=[],
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='make'),
#  'bazel-rules-fuzzing-test-java': Project(name='bazel-rules-fuzzing-test-java',
#                                           language='jvm',
#                                           homepage='https://github.com/bazelbuild/rules_fuzzing',
#                                           main_repo='https://github.com/bazelbuild/rules_fuzzing',
#                                           primary_contact='test@example.com',
#                                           vendor_ccs=None,
#                                           fuzzing_engines=['libfuzzer'],
#                                           build_system='bazel'),
#  'bc-gh': Project(name='bc-gh',
#                   language='c',
#                   homepage='https://git.gavinhoward.com/gavin/bc',
#                   main_repo='https://github.com/gavinhoward/bc',
#                   primary_contact='gavin.d.howard@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer',
#                                    'afl',
#                                    'honggfuzz',
#                                    'centipede'],
#                   build_system='make'),
#  'bc-java': Project(name='bc-java',
#                     language='jvm',
#                     homepage='https://www.bouncycastle.org/',
#                     main_repo='https://github.com/bcgit/bc-java.git',
#                     primary_contact='',
#                     vendor_ccs=['glendowne@code-intelligence.com',
#                                 'wagner@code-intelligence.com',
#                                 'patrice.salathe@code-intelligence.com',
#                                 'yakdan@code-intelligence.com',
#                                 'hlin@code-intelligence.com',
#                                 'bug-disclosure@code-intelligence.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'bearssl': Project(name='bearssl',
#                     language='c++',
#                     homepage='https://bearssl.org/',
#                     main_repo='https://www.bearssl.org/git/BearSSL',
#                     primary_contact='guidovranken@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=None,
#                     build_system='make'),
#  'behaviortreecpp': Project(name='behaviortreecpp',
#                             language='c++',
#                             homepage='https://www.behaviortree.dev/',
#                             main_repo='https://github.com/BehaviorTree/BehaviorTree.CPP',
#                             primary_contact='christopher.krah@tii.ae',
#                             vendor_ccs=['dfaconti@aurynrobotics.com'],
#                             fuzzing_engines=['libfuzzer', 'afl'],
#                             build_system='cmake'),
#  'bignum-fuzzer': Project(name='bignum-fuzzer',
#                           language='c++',
#                           homepage='https://github.com/guidovranken/bignum-fuzzer',
#                           main_repo='https://github.com/guidovranken/bignum-fuzzer',
#                           primary_contact='guidovranken@gmail.com',
#                           vendor_ccs=None,
#                           fuzzing_engines=['libfuzzer', 'honggfuzz'],
#                           build_system='cmake'),
#  'bincode': Project(name='bincode',
#                     language='rust',
#                     homepage='https://github.com/bincode-org/bincode',
#                     main_repo='https://github.com/bincode-org/bincode',
#                     primary_contact='nathan@mccarty.io',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'bind9': Project(name='bind9',
#                   language='c',
#                   homepage='https://gitlab.isc.org/isc-projects/bind9',
#                   main_repo='https://gitlab.isc.org/isc-projects/bind9.git',
#                   primary_contact='ondrej@isc.org',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='make'),
#  'blackfriday': Project(name='blackfriday',
#                         language='go',
#                         homepage='https://github.com/russross/blackfriday',
#                         main_repo='https://github.com/russross/blackfriday',
#                         primary_contact='security-tps@google.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'bluez': Project(name='bluez',
#                   language='c',
#                   homepage='https://github.com/bluez/bluez',
#                   main_repo='https://github.com/bluez/bluez',
#                   primary_contact='bluez.test.bot@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'honggfuzz', 'afl'],
#                   build_system='make'),
#  'boost': Project(name='boost',
#                   language='c++',
#                   homepage='http://www.boost.org/',
#                   main_repo='https://github.com/boostorg/boost.git',
#                   primary_contact='mclow@boost.org',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='unknown'),
#  'boost-beast': Project(name='boost-beast',
#                         language='c++',
#                         homepage='https://www.boost.org/',
#                         main_repo='https://github.com/boostorg/beast.git',
#                         primary_contact='vinnie.falco@gmail.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='unknown'),
#  'boringssl': Project(name='boringssl',
#                       language='c++',
#                       homepage='https://boringssl.googlesource.com/boringssl/',
#                       main_repo='https://boringssl.googlesource.com/boringssl',
#                       primary_contact='agl@google.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=None,
#                       build_system='cmake'),
#  'botan': Project(name='botan',
#                   language='c++',
#                   homepage='https://botan.randombit.net',
#                   main_repo='https://github.com/randombit/botan.git',
#                   primary_contact='jack.lloyd@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl',
#                                    'centipede',
#                                    'honggfuzz',
#                                    'libfuzzer'],
#                   build_system='make'),
#  'brotli-java': Project(name='brotli-java',
#                         language='jvm',
#                         homepage='https://github.com/google/brotli/tree/master/java',
#                         main_repo='https://github.com/google/brotli',
#                         primary_contact='eustas@chromium.org',
#                         vendor_ccs=None,
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'brunsli': Project(name='brunsli',
#                     language='c++',
#                     homepage='https://github.com/google/brunsli',
#                     main_repo='https://github.com/google/brunsli.git',
#                     primary_contact='eustas@chromium.org',
#                     vendor_ccs=['jkew@mozilla.com', 'twsmith@mozilla.com'],
#                     fuzzing_engines=None,
#                     build_system='cmake'),
#  'bson-rust': Project(name='bson-rust',
#                       language='rust',
#                       homepage='https://github.com/mongodb/bson-rust',
#                       main_repo='https://github.com/mongodb/bson-rust',
#                       primary_contact=None,
#                       vendor_ccs=['maxnair.dev@gmail.com'],
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'burntsushi-toml': Project(name='burntsushi-toml',
#                             language='go',
#                             homepage='https://github.com/BurntSushi/toml',
#                             main_repo='https://github.com/BurntSushi/toml',
#                             primary_contact=None,
#                             vendor_ccs=['maxnair.dev@gmail.com'],
#                             fuzzing_engines=['libfuzzer'],
#                             build_system='unknown'),
#  'bzip2': Project(name='bzip2',
#                   language='c++',
#                   homepage='https://sourceware.org/bzip2/',
#                   main_repo=None,
#                   primary_contact='bzip2fuzzer@gmail.com',
#                   vendor_ccs=['twsmith@mozilla.com'],
#                   fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                   build_system='unknown'),
#  'c-blosc': Project(name='c-blosc',
#                     language='c++',
#                     homepage='https://github.com/Blosc/c-blosc',
#                     main_repo='https://github.com/Blosc/c-blosc.git',
#                     primary_contact='blosc.oss.fuzz@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=None,
#                     build_system='cmake'),
#  'caddy': Project(name='caddy',
#                   language='go',
#                   homepage='https://caddyserver.com/',
#                   main_repo='https://github.com/caddyserver/caddy.git',
#                   primary_contact='msaa1990@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='make'),
#  'cairo': Project(name='cairo',
#                   language='c',
#                   homepage='https://gitlab.freedesktop.org/cairo/cairo',
#                   main_repo='https://gitlab.freedesktop.org/cairo/cairo.git',
#                   primary_contact='security-tps@google.com',
#                   vendor_ccs=['jkew@mozilla.com',
#                               'jmuizelaar@mozilla.com',
#                               'twsmith@mozilla.com'],
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='make'),
#  'calcite': Project(name='calcite',
#                     language='jvm',
#                     homepage='https://calcite.apache.org/',
#                     main_repo='https://github.com/apache/calcite/',
#                     primary_contact=None,
#                     vendor_ccs=['wagner@code-intelligence.com',
#                                 'yakdan@code-intelligence.com',
#                                 'patrice.salathe@code-intelligence.com',
#                                 'hlin@code-intelligence.com',
#                                 'bug-disclosure@code-intelligence.com'],
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'calcite-avatica': Project(name='calcite-avatica',
#                             language='jvm',
#                             homepage='https://github.com/apache/calcite-avatica',
#                             main_repo='https://github.com/apache/calcite-avatica',
#                             primary_contact=None,
#                             vendor_ccs=['david@adalogics.com',
#                                         'adam@adalogics.com',
#                                         'arthur.chan@adalogics.com'],
#                             fuzzing_engines=['libfuzzer'],
#                             build_system='unknown'),
#  'canvg': Project(name='canvg',
#                   language='javascript',
#                   homepage='https://canvg.js.org/',
#                   main_repo='https://github.com/canvg/canvg',
#                   primary_contact=None,
#                   vendor_ccs=['wagner@code-intelligence.com',
#                               'yakdan@code-intelligence.com',
#                               'glendowne@code-intelligence.com',
#                               'patrice.salathe@code-intelligence.com',
#                               'hlin@code-intelligence.com',
#                               'christopher.krah@code-intelligence.com',
#                               'bug-disclosure@code-intelligence.com'],
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='unknown'),
#  'capnproto': Project(name='capnproto',
#                       language='c++',
#                       homepage='https://capnproto.org',
#                       main_repo='https://github.com/capnproto/capnproto',
#                       primary_contact='security@sandstorm.io',
#                       vendor_ccs=None,
#                       fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                       build_system='make'),
#  'cbor-java': Project(name='cbor-java',
#                       language='jvm',
#                       homepage='https://android.googlesource.com/platform/external/cbor-java/+/refs/heads/master',
#                       main_repo='https://android.googlesource.com/platform/external/cbor-java/+/refs/heads/master',
#                       primary_contact='constantin.rack@gmail.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'cel-cpp': Project(name='cel-cpp',
#                     language='c++',
#                     homepage='https://opensource.google/projects/cel',
#                     main_repo='https://github.com/google/cel-cpp',
#                     primary_contact='kyessenov@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='bazel'),
#  'cglib': Project(name='cglib',
#                   language='jvm',
#                   homepage='https://github.com/cglib/cglib/wiki',
#                   main_repo='https://github.com/cglib/cglib',
#                   primary_contact=None,
#                   vendor_ccs=['wagner@code-intelligence.com',
#                               'yakdan@code-intelligence.com',
#                               'glendowne@code-intelligence.com',
#                               'patrice.salathe@code-intelligence.com',
#                               'hlin@code-intelligence.com',
#                               'schaich@code-intelligence.com',
#                               'bug-disclosure@code-intelligence.com'],
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='unknown'),
#  'checker-framework': Project(name='checker-framework',
#                               language='jvm',
#                               homepage='https://github.com/typetools/checker-framework',
#                               main_repo='git@github.com:typetools/checker-framework.git',
#                               primary_contact='michael.ernst@gmail.com',
#                               vendor_ccs=['wagner@code-intelligence.com',
#                                           'yakdan@code-intelligence.com',
#                                           'glendowne@code-intelligence.com',
#                                           'patrice.salathe@code-intelligence.com',
#                                           'hlin@code-intelligence.com',
#                                           'jacek.trossen@code-intelligence.com',
#                                           'bug-disclosure@code-intelligence.com'],
#                               fuzzing_engines=['libfuzzer'],
#                               build_system='unknown'),
#  'circl': Project(name='circl',
#                   language='c++',
#                   homepage='https://github.com/cloudflare/circl',
#                   main_repo='https://github.com/cloudflare/circl.git',
#                   primary_contact='guidovranken@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=None,
#                   build_system='make'),
#  'cjson': Project(name='cjson',
#                   language='c++',
#                   homepage='https://github.com/DaveGamble/cJSON',
#                   main_repo='https://github.com/DaveGamble/cJSON.git',
#                   primary_contact='max@maxbruckner.de',
#                   vendor_ccs=None,
#                   fuzzing_engines=None,
#                   build_system='unknown'),
#  'clock': Project(name='clock',
#                   language='go',
#                   homepage='https://github.com/benbjohnson/clock',
#                   main_repo='https://github.com/benbjohnson/clock',
#                   primary_contact=None,
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='unknown'),
#  'closure-library': Project(name='closure-library',
#                             language='javascript',
#                             homepage='https://developers.google.com/closure/library/',
#                             main_repo='https://github.com/google/closure-library',
#                             primary_contact=None,
#                             vendor_ccs=['wagner@code-intelligence.com',
#                                         'yakdan@code-intelligence.com',
#                                         'glendowne@code-intelligence.com',
#                                         'patrice.salathe@code-intelligence.com',
#                                         'hlin@code-intelligence.com',
#                                         'christopher.krah@code-intelligence.com',
#                                         'bug-disclosure@code-intelligence.com'],
#                             fuzzing_engines=['libfuzzer'],
#                             build_system='unknown'),
#  'cmake': Project(name='cmake',
#                   language='c',
#                   homepage='https://gitlab.kitware.com/cmake/cmake',
#                   main_repo='https://gitlab.kitware.com/cmake/cmake',
#                   primary_contact='brad.king@kitware.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='cmake'),
#  'cmark': Project(name='cmark',
#                   language='c++',
#                   homepage='http://commonmark.org',
#                   main_repo='https://github.com/commonmark/cmark.git',
#                   primary_contact='jgm@berkeley.edu',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                   build_system='cmake'),
#  'cockroachdb': Project(name='cockroachdb',
#                         language='go',
#                         homepage='https://www.cockroachlabs.com/',
#                         main_repo='https://github.com/cockroachdb/cockroach.git',
#                         primary_contact='stan@cockroachlabs.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'connectedhomeip': Project(name='connectedhomeip',
#                             language='c++',
#                             homepage='https://buildwithmatter.com/',
#                             main_repo='https://github.com/project-chip/connectedhomeip.git',
#                             primary_contact='andreilitvin@google.com',
#                             vendor_ccs=None,
#                             fuzzing_engines=['libfuzzer',
#                                              'honggfuzz',
#                                              'centipede'],
#                             build_system='ninja'),
#  'coreutils': Project(name='coreutils',
#                       language=None,
#                       homepage='http://www.gnu.org/software/coreutils/',
#                       main_repo='https://github.com/coreutils/coreutils',
#                       primary_contact='P@draigBrady.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=None,
#                       build_system=None),
#  'cpp-httplib': Project(name='cpp-httplib',
#                         language='c++',
#                         homepage='https://github.com/yhirose/cpp-httplib',
#                         main_repo='https://github.com/yhirose/cpp-httplib.git',
#                         primary_contact='yuji.hirose.bug@gmail.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='make'),
#  'cpuinfo': Project(name='cpuinfo',
#                     language='c',
#                     homepage='https://github.com/pytorch/cpuinfo',
#                     main_repo='https://github.com/pytorch/cpuinfo',
#                     primary_contact=None,
#                     vendor_ccs=['david@adalogics.com'],
#                     fuzzing_engines=None,
#                     build_system='cmake'),
#  'cri-o': Project(name='cri-o',
#                   language='go',
#                   homepage='https://cri-o.io/',
#                   main_repo='https://github.com/cri-o/cri-o',
#                   primary_contact='cncf-crio-security@lists.cncf.io',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='unknown'),
#  'cura-engine': Project(name='cura-engine',
#                         language='c++',
#                         homepage='https://github.com/Ultimaker/CuraEngine',
#                         main_repo='https://github.com/Ultimaker/CuraEngine.git',
#                         primary_contact='j.vankessel@ultimaker.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system=None),
#  'curvesapi': Project(name='curvesapi',
#                       language='jvm',
#                       homepage='https://github.com/virtuald/curvesapi',
#                       main_repo='https://github.com/virtuald/curvesapi',
#                       primary_contact=None,
#                       vendor_ccs=['david@adalogics.com',
#                                   'adam@adalogics.com',
#                                   'arthur.chan@adalogics.com'],
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'cxxopts': Project(name='cxxopts',
#                     language='c++',
#                     homepage='https://github.com/jarro2783/cxxopts',
#                     main_repo='https://github.com/jarro2783/cxxopts',
#                     primary_contact='jarro.2783@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='bazel'),
#  'data-encoding': Project(name='data-encoding',
#                           language='rust',
#                           homepage='https://github.com/ia0/data-encoding',
#                           main_repo='https://github.com/ia0/data-encoding.git',
#                           primary_contact='github@ia0.eu',
#                           vendor_ccs=['arthur.chan@adalogics.com',
#                                       'david@adalogics.com'],
#                           fuzzing_engines=['libfuzzer'],
#                           build_system='unknown'),
#  'dav1d': Project(name='dav1d',
#                   language='c++',
#                   homepage='https://code.videolan.org/videolan/dav1d',
#                   main_repo='https://code.videolan.org/videolan/dav1d.git',
#                   primary_contact='janne.grunau@gmail.com',
#                   vendor_ccs=['twsmith@mozilla.com'],
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='ninja'),
#  'dbus-broker': Project(name='dbus-broker',
#                         language='c',
#                         homepage='https://github.com/bus1/dbus-broker',
#                         main_repo='https://github.com/bus1/dbus-broker',
#                         primary_contact='david.rheinsberg@gmail.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='make'),
#  'dlplibs': Project(name='dlplibs',
#                     language='c++',
#                     homepage='https://www.documentliberation.org',
#                     main_repo=None,
#                     primary_contact='dtardon@redhat.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'dng_sdk': Project(name='dng_sdk',
#                     language='c++',
#                     homepage='https://android.googlesource.com/platform/external/dng_sdk/',
#                     main_repo='https://android.googlesource.com/platform/external/dng_sdk/',
#                     primary_contact='adaubert@google.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='unknown'),
#  'dnsmasq': Project(name='dnsmasq',
#                     language='c',
#                     homepage='https://thekelleys.org.uk/dnsmasq/doc.html',
#                     main_repo='git://thekelleys.org.uk/dnsmasq.git',
#                     primary_contact='simon@thekelleys.org.uk',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'docker-client': Project(name='docker-client',
#                           language='jvm',
#                           homepage='https://github.com/spotify/docker-client',
#                           main_repo='https://github.com/spotify/docker-client',
#                           primary_contact=None,
#                           vendor_ccs=['david@adalogics.com',
#                                       'adam@adalogics.com',
#                                       'arthur.chan@adalogics.com'],
#                           fuzzing_engines=['libfuzzer'],
#                           build_system='unknown'),
#  'dom4j': Project(name='dom4j',
#                   language='jvm',
#                   homepage='https://github.com/dom4j/dom4j',
#                   main_repo='https://github.com/dom4j/dom4j.git',
#                   primary_contact=None,
#                   vendor_ccs=['wagner@code-intelligence.com',
#                               'yakdan@code-intelligence.com',
#                               'glendowne@code-intelligence.com',
#                               'patrice.salathe@code-intelligence.com',
#                               'hlin@code-intelligence.com',
#                               'bug-disclosure@code-intelligence.com'],
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='unknown'),
#  'double-conversion': Project(name='double-conversion',
#                               language='c++',
#                               homepage='https://github.com/google/double-conversion',
#                               main_repo='https://github.com/google/double-conversion.git',
#                               primary_contact='florian@loitsch.com',
#                               vendor_ccs=None,
#                               fuzzing_engines=None,
#                               build_system='cmake'),
#  'dovecot': Project(name='dovecot',
#                     language='c',
#                     homepage='https://www.dovecot.org/',
#                     main_repo='https://github.com/dovecot/core',
#                     primary_contact='oss-fuzz@open-xchange.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'dpp': Project(name='dpp',
#                 language='c++',
#                 homepage='https://github.com/brainboxdotcc/DPP',
#                 main_repo='https://github.com/brainboxdotcc/DPP.git',
#                 primary_contact='craigedwardsbrainbox@gmail.com',
#                 vendor_ccs=None,
#                 fuzzing_engines=None,
#                 build_system=None),
#  'draco': Project(name='draco',
#                   language='c++',
#                   homepage='https://github.com/google/draco',
#                   main_repo='https://github.com/google/draco',
#                   primary_contact='fgalligan@google.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'honggfuzz', 'centipede'],
#                   build_system='unknown'),
#  'dragonfly': Project(name='dragonfly',
#                       language='go',
#                       homepage='https://github.com/dragonflyoss/Dragonfly',
#                       main_repo='https://github.com/dragonflyoss/Dragonfly',
#                       primary_contact='zj3142063@gmail.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'e2fsprogs': Project(name='e2fsprogs',
#                       language='c',
#                       homepage='https://github.com/tytso/e2fsprogs',
#                       main_repo='https://github.com/tytso/e2fsprogs',
#                       primary_contact='tytso@mit.edu',
#                       vendor_ccs=None,
#                       fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                       build_system='make'),
#  'ecc-diff-fuzzer': Project(name='ecc-diff-fuzzer',
#                             language='c++',
#                             homepage='https://github.com/catenacyber/elliptic-curve-differential-fuzzer',
#                             main_repo='https://github.com/catenacyber/elliptic-curve-differential-fuzzer',
#                             primary_contact='p.antoine@catenacyber.fr',
#                             vendor_ccs=None,
#                             fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                             build_system='cmake'),
#  'eclipse-equinox': Project(name='eclipse-equinox',
#                             language='jvm',
#                             homepage='https://github.com/eclipse-equinox/equinox',
#                             main_repo='https://github.com/eclipse-equinox/equinox',
#                             primary_contact=None,
# ...
#                         vendor_ccs=None,
#                         fuzzing_engines=None,
#                         build_system='make'),
#  'openweave': Project(name='openweave',
#                       language='c++',
#                       homepage='https://openweave.io',
#                       main_repo='https://github.com/openweave/openweave-core',
#                       primary_contact='szewczyk@google.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='make'),
#  'osquery': Project(name='osquery',
#                     language='c++',
#                     homepage='https://osquery.io',
#                     main_repo='https://github.com/osquery/osquery',
#                     primary_contact='osquery@osquery.io',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer', 'afl'],
#                     build_system='cmake'),
#  'ots': Project(name='ots',
#                 language='c++',
#                 homepage='https://github.com/khaledhosny/ots',
#                 main_repo='https://github.com/khaledhosny/ots.git',
#                 primary_contact='dr.khaled.hosny@gmail.com',
#                 vendor_ccs=['jmuizelaar@mozilla.com',
#                             'lsalzman@mozilla.com',
#                             'twsmith@mozilla.com'],
#                 fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                 build_system='ninja'),
#  'ox-ruby': Project(name='ox-ruby',
#                     language='ruby',
#                     homepage='https://github.com/ohler55/ox',
#                     main_repo='https://github.com/ohler55/ox',
#                     primary_contact='TODO@template.test',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer'],
#                     build_system='unknown'),
#  'p11-kit': Project(name='p11-kit',
#                     language='c',
#                     homepage='https://p11-glue.github.io/p11-glue/p11-kit.html',
#                     main_repo='https://github.com/p11-glue/p11-kit',
#                     primary_contact='daiki.ueno@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'pacemaker': Project(name='pacemaker',
#                       language='c',
#                       homepage='https://www.clusterlabs.org/pacemaker/',
#                       main_repo='https://github.com/ClusterLabs/pacemaker',
#                       primary_contact='clumens@redhat.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=None,
#                       build_system='make'),
#  'pcl': Project(name='pcl',
#                 language='c++',
#                 homepage='http://pointclouds.org',
#                 main_repo='https://github.com/pointcloudlibrary/pcl',
#                 primary_contact='kunal.tyagi.3.1994@gmail.com',
#                 vendor_ccs=None,
#                 fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                 build_system='unknown'),
#  'pcre2': Project(name='pcre2',
#                   language='c++',
#                   homepage='http://www.pcre.org/',
#                   main_repo='https://github.com/PCRE2Project/pcre2',
#                   primary_contact='nicholas@nickcwilson.co.uk',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'afl'],
#                   build_system='make'),
#  'pdfminersix': Project(name='pdfminersix',
#                         language='python',
#                         homepage='https://pdfminersix.readthedocs.io/en/latest/',
#                         main_repo='https://github.com/pdfminer/pdfminer.six',
#                         primary_contact='pietermarsman@gmail.com',
#                         vendor_ccs=None,
#                         fuzzing_engines=['libfuzzer'],
#                         build_system=None),
#  'pffft': Project(name='pffft',
#                   language='c++',
#                   homepage='https://bitbucket.org/jpommier/pffft',
#                   main_repo='https://bitbucket.org/jpommier/pffft.git',
#                   primary_contact='pommier@modartt.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                   build_system='unknown'),
#  'phmap': Project(name='phmap',
#                   language='c++',
#                   homepage='https://github.com/greg7mdp/parallel-hashmap',
#                   main_repo='https://github.com/greg7mdp/parallel-hashmap',
#                   primary_contact='greg7mdp@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system='unknown'),
#  'php': Project(name='php',
#                 language='c++',
#                 homepage='http://php.net/',
#                 main_repo='https://github.com/php/php-src.git',
#                 primary_contact='stas@php.net',
#                 vendor_ccs=None,
#                 fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                 build_system='make'),
#  'picotls': Project(name='picotls',
#                     language='c++',
#                     homepage='https://github.com/h2o/picotls',
#                     main_repo='https://github.com/h2o/picotls',
#                     primary_contact='jonathan.foote@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='cmake'),
#  'pigweed': Project(name='pigweed',
#                     language='c++',
#                     homepage='https://pigweed.dev/',
#                     main_repo='https://pigweed.googlesource.com/pigweed/pigweed',
#                     primary_contact='keir@google.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl',
#                                      'centipede',
#                                      'honggfuzz',
#                                      'libfuzzer'],
#                     build_system='bazel'),
#  'pikepdf': Project(name='pikepdf',
#                     language='python',
#                     homepage='https://pikepdf.readthedocs.io/en/latest/index.html',
#                     main_repo='https://github.com/pikepdf/pikepdf.git',
#                     primary_contact='james@purplerock.ca',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer'],
#                     build_system=None),
#  'pjsip': Project(name='pjsip',
#                   language='c',
#                   homepage='www.pjsip.org',
#                   main_repo='https://github.com/pjsip/pjproject',
#                   primary_contact='security@pjsip.org',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                   build_system='make'),
#  'plan9port': Project(name='plan9port',
#                       language='c',
#                       homepage='https://github.com/9fans/plan9port',
#                       main_repo='https://github.com/9fans/plan9port',
#                       primary_contact=None,
#                       vendor_ccs=['david@adalogics.com'],
#                       fuzzing_engines=None,
#                       build_system='unknown'),
#  'poppler': Project(name='poppler',
#                     language='c++',
#                     homepage='https://poppler.freedesktop.org/',
#                     main_repo='https://anongit.freedesktop.org/git/poppler/poppler.git',
#                     primary_contact='tsdgeos@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='cmake'),
#  'postfix': Project(name='postfix',
#                     language='c',
#                     homepage='http://www.postfix.org/',
#                     main_repo='https://github.com/vdukhovni/postfix',
#                     primary_contact='wietse@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=None,
#                     build_system='make'),
#  'postgis': Project(name='postgis',
#                     language='c++',
#                     homepage='http://postgis.net/',
#                     main_repo='https://git.osgeo.org/gitea/postgis/postgis.git',
#                     primary_contact='lr@pcorp.us',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make'),
#  'proftpd': Project(name='proftpd',
#                     language='c',
#                     homepage='http://www.proftpd.org/',
#                     main_repo='https://github.com/proftpd/proftpd',
#                     primary_contact='castaglian@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='unknown'),
#  'proj4': Project(name='proj4',
#                   language='c++',
#                   homepage='https://proj.org/',
#                   main_repo='https://github.com/OSGeo/PROJ',
#                   primary_contact='even.rouault@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                   build_system=None),
#  'prost': Project(name='prost',
#                   language='rust',
#                   homepage='https://crates.io/crates/prost',
#                   main_repo='https://github.com/tokio-rs/prost',
#                   primary_contact='luciofranco14@gmail.com',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer'],
#                   build_system='unknown'),
#  'protobuf-java': Project(name='protobuf-java',
#                           language='jvm',
#                           homepage='https://developers.google.com/protocol-buffers/',
#                           main_repo='https://github.com/protocolbuffers/protobuf',
#                           primary_contact='kfm@google.com',
#                           vendor_ccs=['norbert.schneider@code-intelligence.com',
#                                       'hlin@code-intelligence.com',
#                                       'bug-disclosure@code-intelligence.com'],
#                           fuzzing_engines=['libfuzzer'],
#                           build_system='bazel'),
#  'protobuf-js': Project(name='protobuf-js',
#                         language='javascript',
#                         homepage='https://github.com/protobufjs/protobuf.js',
#                         main_repo='https://github.com/protobufjs/protobuf.js',
#                         primary_contact=None,
#                         vendor_ccs=['wagner@code-intelligence.com',
#                                     'yakdan@code-intelligence.com',
#                                     'glendowne@code-intelligence.com',
#                                     'patrice.salathe@code-intelligence.com',
#                                     'hlin@code-intelligence.com',
#                                     'christopher.krah@code-intelligence.com',
#                                     'bug-disclosure@code-intelligence.com'],
#                         fuzzing_engines=['libfuzzer'],
#                         build_system='unknown'),
#  'protoc-gen-validate': Project(name='protoc-gen-validate',
#                                 language='go',
#                                 homepage='https://github.com/bufbuild/protoc-gen-validate',
#                                 main_repo='https://github.com/bufbuild/protoc-gen-validate',
#                                 primary_contact=None,
#                                 vendor_ccs=None,
#                                 fuzzing_engines=['libfuzzer'],
#                                 build_system='make'),
#  'proton-bridge': Project(name='proton-bridge',
#                           language='go',
#                           homepage='https://proton.me',
#                           main_repo='https://github.com/ProtonMail/proton-bridge',
#                           primary_contact='security@proton.me',
#                           vendor_ccs=None,
#                           fuzzing_engines=['libfuzzer'],
#                           build_system='unknown'),
#  'publicsuffix-list': Project(name='publicsuffix-list',
#                               language='go',
#                               homepage='https://github.com/publicsuffix/list',
#                               main_repo='https://github.com/publicsuffix/list',
#                               primary_contact=None,
#                               vendor_ccs=None,
#                               fuzzing_engines=['libfuzzer'],
#                               build_system='unknown'),
#  'pugixml': Project(name='pugixml',
#                     language='c++',
#                     homepage='https://github.com/zeux/pugixml',
#                     main_repo='https://github.com/zeux/pugixml',
#                     primary_contact='arseny.kapoulkine@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='unknown'),
#  'pupnp': Project(name='pupnp',
#                   language='c',
#                   homepage='https://pupnp.github.io/pupnp/',
#                   main_repo='https://github.com/pupnp/pupnp',
#                   primary_contact='mroberto@users.sourceforge.net',
#                   vendor_ccs=['virtual_worlds@gmx.de'],
#                   fuzzing_engines=['libfuzzer', 'afl', 'honggfuzz'],
#                   build_system='cmake'),
#  'python3-libraries': Project(name='python3-libraries',
#                               language='c',
#                               homepage='https://www.python.org/',
#                               main_repo='https://github.com/python/cpython',
#                               primary_contact='seth@python.org',
#                               vendor_ccs=None,
#                               fuzzing_engines=['libfuzzer', 'honggfuzz'],
#                               build_system='make'),
#  'pyvex': Project(name='pyvex',
#                   language='python',
#                   homepage='https://api.angr.io/projects/pyvex/en/latest/api.html',
#                   main_repo='https://github.com/angr/pyvex.git',
#                   primary_contact='angr-dev@asu.edu',
#                   vendor_ccs=None,
#                   fuzzing_engines=['libfuzzer'],
#                   build_system=None),
#  'qpid-proton': Project(name='qpid-proton',
#                         language='c++',
#                         homepage='https://qpid.apache.org/proton/',
#                         main_repo='https://github.com/apache/qpid-proton.git',
#                         primary_contact='jross@apache.org',
#                         vendor_ccs=None,
#                         fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                         build_system='cmake'),
#  'quic-go': Project(name='quic-go',
#                     language='go',
#                     homepage='https://github.com/quic-go/quic-go',
#                     main_repo='https://github.com/quic-go/quic-go',
#                     primary_contact='martenseemann@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['libfuzzer'],
#                     build_system=None),
#  'quick-xml': Project(name='quick-xml',
#                       language='rust',
#                       homepage='https://github.com/tafia/quick-xml',
#                       main_repo='https://github.com/tafia/quick-xml',
#                       primary_contact='tafia973@gmail.com',
#                       vendor_ccs=None,
#                       fuzzing_engines=['libfuzzer'],
#                       build_system='unknown'),
#  'quickjs': Project(name='quickjs',
#                     language='c',
#                     homepage='https://bellard.org/quickjs/',
#                     main_repo='https://github.com/bellard/quickjs',
#                     primary_contact='fabrice.bellard@gmail.com',
#                     vendor_ccs=None,
#                     fuzzing_engines=['afl', 'honggfuzz', 'libfuzzer'],
#                     build_system='make')}

# %% [markdown]
# Thanks for reading! I hope some of this proves useful.
